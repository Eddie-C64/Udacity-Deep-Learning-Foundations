# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    if labels[i] == "POSITIVE":
        for word in reviews[i].split(" "):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895),
#  ('has', 9186),
#  ('so', 9154),
#  ('like', 9038),
#  ('about', 8313),
#  ('very', 8305),
#  ('out', 8134),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7737),
#  ('or', 7732),
#  ('good', 7720),
#  ('more', 7521),
#  ('when', 7456),
#  ('some', 7441),
#  ('if', 7285),
#  ('just', 7152),
#  ('can', 7001),
#  ('story', 6780),
#  ('time', 6515),
#  ('my', 6488),
#  ('great', 6419),
#  ('well', 6405),
#  ('up', 6321),
#  ('which', 6267),
#  ('their', 6107),
#  ('see', 6026),
#  ('also', 5550),
#  ('we', 5531),
#  ('really', 5476),
#  ('would', 5400),
#  ('will', 5218),
#  ('me', 5167),
#  ('had', 5148),
#  ('only', 5137),
#  ('him', 5018),
#  ('even', 4964),
#  ('most', 4864),
#  ('other', 4858),
#  ('were', 4782),
#  ('first', 4755),
#  ('than', 4736),
#  ('much', 4685),
#  ('its', 4622),
#  ('no', 4574),
#  ('into', 4544),
#  ('people', 4479),
#  ('best', 4319),
#  ('love', 4301),
#  ('get', 4272),
#  ('how', 4213),
#  ('life', 4199),
#  ('been', 4189),
#  ('because', 4079),
#  ('way', 4036),
#  ('do', 3941),
#  ('made', 3823),
#  ('films', 3813),
#  ('them', 3805),
#  ('after', 3800),
#  ('many', 3766),
#  ('two', 3733),
#  ('too', 3659),
#  ('think', 3655),
#  ('movies', 3586),
#  ('characters', 3560),
#  ('character', 3514),
#  ('don', 3468),
#  ('man', 3460),
#  ('show', 3432),
#  ('watch', 3424),
#  ('seen', 3414),
#  ('then', 3358),
#  ('little', 3341),
#  ('still', 3340),
#  ('make', 3303),
#  ('could', 3237),
#  ('never', 3226),
#  ('being', 3217),
#  ('where', 3173),
#  ('does', 3069),
#  ('over', 3017),
#  ('any', 3002),
#  ('while', 2899),
#  ('know', 2833),
#  ('did', 2790),
#  ('years', 2758),
#  ('here', 2740),
#  ('ever', 2734),
#  ('end', 2696),
#  ('these', 2694),
#  ('such', 2590),
#  ('real', 2568),
#  ('scene', 2567),
#  ('back', 2547),
#  ('those', 2485),
#  ('though', 2475),
#  ('off', 2463),
#  ('new', 2458),
#  ('your', 2453),
#  ('go', 2440),
#  ('acting', 2437),
#  ('plot', 2432),
#  ('world', 2429),
#  ('scenes', 2427),
#  ('say', 2414),
#  ('through', 2409),
#  ('makes', 2390),
#  ('better', 2381),
#  ('now', 2368),
#  ('work', 2346),
#  ('young', 2343),
#  ('old', 2311),
#  ('ve', 2307),
#  ('find', 2272),
#  ('both', 2248),
#  ('before', 2177),
#  ('us', 2162),
#  ('again', 2158),
#  ('series', 2153),
#  ('quite', 2143),
#  ('something', 2135),
#  ('cast', 2133),
#  ('should', 2121),
#  ('part', 2098),
#  ('always', 2088),
#  ('lot', 2087),
#  ('another', 2075),
#  ('actors', 2047),
#  ('director', 2040),
#  ('family', 2032),
#  ('own', 2016),
#  ('between', 2016),
#  ('m', 1998),
#  ('may', 1997),
#  ('same', 1972),
#  ('role', 1967),
#  ('watching', 1966),
#  ('every', 1954),
#  ('funny', 1953),
#  ('doesn', 1935),
#  ('performance', 1928),
#  ('few', 1918),
#  ('bad', 1907),
#  ('look', 1900),
#  ('re', 1884),
#  ('why', 1855),
#  ('things', 1849),
#  ('times', 1832),
#  ('big', 1815),
#  ('however', 1795),
#  ('actually', 1790),
#  ('action', 1789),
#  ('going', 1783),
#  ('bit', 1757),
#  ('comedy', 1742),
#  ('down', 1740),
#  ('music', 1738),
#  ('must', 1728),
#  ('take', 1709),
#  ('saw', 1692),
#  ('long', 1690),
#  ('right', 1688),
#  ('fun', 1686),
#  ('fact', 1684),
#  ('excellent', 1683),
#  ('around', 1674),
#  ('didn', 1672),
#  ('without', 1671),
#  ('thing', 1662),
#  ('thought', 1639),
#  ('got', 1635),
#  ('each', 1630),
#  ('day', 1614),
#  ('feel', 1597),
#  ('seems', 1596),
#  ('come', 1594),
#  ('done', 1586),
#  ('beautiful', 1580),
#  ('especially', 1572),
#  ('played', 1571),
#  ('almost', 1566),
#  ('want', 1562),
#  ('yet', 1556),
#  ('give', 1553),
#  ('pretty', 1549),
#  ('last', 1543),
#  ('since', 1519),
#  ('different', 1504),
#  ('although', 1501),
#  ('gets', 1490),
#  ('true', 1487),
#  ('interesting', 1481),
#  ('job', 1470),
#  ('enough', 1455),
#  ('our', 1454),
#  ('shows', 1447),
#  ('horror', 1441),
#  ('woman', 1439),
#  ('tv', 1400),
#  ('probably', 1398),
#  ('father', 1395),
#  ('original', 1393),
#  ('girl', 1390),
#  ('point', 1379),
#  ('plays', 1378),
#  ('wonderful', 1372),
#  ('course', 1358),
#  ('far', 1358),
#  ('john', 1350),
#  ('rather', 1340),
#  ('isn', 1328),
#  ('ll', 1326),
#  ('dvd', 1324),
#  ('later', 1324),
#  ('whole', 1310),
#  ('war', 1310),
#  ('d', 1307),
#  ('away', 1306),
#  ('found', 1306),
#  ('screen', 1305),
#  ('nothing', 1300),
#  ('year', 1297),
#  ('once', 1296),
#  ('hard', 1294),
#  ('together', 1280),
#  ('am', 1277),
#  ('set', 1277),
#  ('having', 1266),
#  ('making', 1265),
#  ('place', 1263),
#  ('comes', 1260),
#  ('might', 1260),
#  ('sure', 1253),
#  ('american', 1248),
#  ('play', 1245),
#  ('kind', 1244),
#  ('perfect', 1242),
#  ('takes', 1242),
#  ('performances', 1237),
#  ('himself', 1230),
#  ('worth', 1221),
#  ('everyone', 1221),
#  ('anyone', 1214),
#  ('actor', 1203),
#  ('three', 1201),
#  ('wife', 1196),
#  ('classic', 1192),
#  ('goes', 1186),
#  ('ending', 1178),
#  ('version', 1168),
#  ('star', 1149),
#  ('enjoy', 1146),
#  ('book', 1142),
#  ('nice', 1132),
#  ('everything', 1128),
#  ('during', 1124),
#  ('put', 1118),
#  ('seeing', 1111),
#  ('least', 1102),
#  ('house', 1100),
#  ('high', 1095),
#  ('watched', 1094),
#  ('men', 1087),
#  ('loved', 1087),
#  ('night', 1082),
#  ('anything', 1075),
#  ('guy', 1071),
#  ('believe', 1071),
#  ('top', 1063),
#  ('amazing', 1058),
#  ('hollywood', 1056),
#  ('looking', 1053),
#  ('main', 1044),
#  ('definitely', 1043),
#  ('gives', 1031),
#  ('home', 1029),
#  ('seem', 1028),
#  ('episode', 1023),
#  ('sense', 1020),
#  ('audience', 1020),
#  ('truly', 1017),
#  ('special', 1011),
#  ('short', 1009),
#  ('second', 1009),
#  ('fan', 1009),
#  ('mind', 1005),
#  ('human', 1001),
#  ('recommend', 999),
#  ('full', 996),
#  ('black', 995),
#  ('help', 991),
#  ('along', 989),
#  ('trying', 987),
#  ('small', 986),
#  ('death', 985),
#  ('friends', 981),
#  ('remember', 974),
#  ('often', 970),
#  ('said', 966),
#  ('favorite', 962),
#  ('heart', 959),
#  ('early', 957),
#  ('left', 956),
#  ('until', 955),
#  ('let', 954),
#  ('script', 954),
#  ('maybe', 937),
#  ('today', 936),
#  ('live', 934),
#  ('less', 934),
#  ('moments', 933),
#  ('others', 929),
#  ('brilliant', 926),
#  ('shot', 925),
#  ('liked', 923),
#  ('become', 916),
#  ('won', 915),
#  ('used', 910),
#  ('style', 907),
#  ('mother', 895),
#  ('lives', 894),
#  ('came', 893),
#  ('stars', 890),
#  ('cinema', 889),
#  ('looks', 885),
#  ('perhaps', 884),
#  ('read', 882),
#  ('enjoyed', 879),
#  ('boy', 875),
#  ('drama', 873),
#  ('highly', 871),
#  ('given', 870),
#  ('playing', 867),
#  ('use', 864),
#  ('next', 859),
#  ('women', 858),
#  ('fine', 857),
#  ('effects', 856),
#  ('kids', 854),
#  ('entertaining', 853),
#  ('need', 852),
#  ('line', 850),
#  ('works', 848),
#  ('someone', 847),
#  ('mr', 836),
#  ('simply', 835),
#  ('picture', 833),
#  ('children', 833),
#  ('friend', 831),
#  ('keep', 831),
#  ('face', 831),
#  ('dark', 830),
#  ('certainly', 828),
#  ('overall', 828),
#  ('minutes', 827),
#  ('wasn', 824),
#  ('history', 822),
#  ('finally', 820),
#  ('couple', 816),
#  ('against', 815),
#  ('son', 809),
#  ('understand', 808),
#  ('lost', 807),
#  ('michael', 805),
#  ('else', 801),
#  ('throughout', 798),
#  ('fans', 797),
#  ('city', 792),
#  ('reason', 789),
#  ('production', 787),
#  ('written', 787),
#  ('several', 784),
#  ('school', 783),
#  ('rest', 781),
#  ('based', 781),
#  ('try', 780),
#  ('dead', 776),
#  ('hope', 775),
#  ('strong', 768),
#  ('white', 765),
#  ('tell', 759),
#  ('itself', 758),
#  ('half', 753),
#  ('person', 749),
#  ('sometimes', 746),
#  ('past', 744),
#  ('start', 744),
#  ('genre', 743),
#  ('beginning', 739),
#  ('final', 739),
#  ('town', 738),
#  ('art', 734),
#  ('game', 732),
#  ('humor', 732),
#  ('yes', 731),
#  ('idea', 731),
#  ('late', 730),
#  ('despite', 729),
#  ('becomes', 729),
#  ('case', 726),
#  ('able', 726),
#  ('money', 723),
#  ('child', 721),
#  ('completely', 721),
#  ('side', 719),
#  ('camera', 716),
#  ('getting', 714),
#  ('instead', 712),
#  ('soon', 702),
#  ('under', 700),
#  ('viewer', 699),
#  ('age', 697),
#  ('days', 696),
#  ('stories', 696),
#  ('felt', 694),
#  ('simple', 694),
#  ('roles', 693),
#  ('video', 688),
#  ('either', 683),
#  ('name', 683),
#  ('doing', 677),
#  ('turns', 674),
#  ('wants', 671),
#  ('close', 671),
#  ('title', 669),
#  ('wrong', 668),
#  ('went', 666),
#  ('james', 665),
#  ('evil', 659),
#  ('episodes', 657),
#  ('budget', 657),
#  ('relationship', 655),
#  ('fantastic', 653),
#  ('piece', 653),
#  ('david', 651),
#  ('turn', 648),
#  ('murder', 646),
#  ('parts', 645),
#  ('brother', 644),
#  ('absolutely', 643),
#  ('head', 643),
#  ('experience', 642),
#  ('eyes', 641),
#  ('sex', 638),
#  ('direction', 637),
#  ('called', 637),
#  ('directed', 636),
#  ('lines', 634),
#  ('behind', 633),
#  ('sort', 632),
#  ('actress', 631),
#  ('lead', 630),
#  ('oscar', 628),
#  ('example', 627),
#  ('including', 627),
#  ('musical', 625),
#  ('known', 625),
#  ('chance', 621),
#  ('score', 620),
#  ('feeling', 619),
#  ('already', 619),
#  ('hit', 619),
#  ('voice', 615),
#  ('moment', 612),
#  ('living', 612),
#  ('supporting', 610),
#  ('low', 610),
#  ('ago', 609),
#  ('themselves', 608),
#  ('hilarious', 605),
#  ('reality', 605),
#  ('jack', 604),
#  ('told', 603),
#  ('hand', 601),
#  ('dialogue', 600),
#  ('quality', 600),
#  ('moving', 600),
#  ('happy', 599),
#  ('song', 599),
#  ('matter', 598),
#  ('paul', 598),
#  ('light', 594),
#  ('future', 593),
#  ('entire', 592),
#  ('finds', 591),
#  ('gave', 589),
#  ('laugh', 587),
#  ('released', 586),
#  ('expect', 584),
#  ('fight', 581),
#  ('particularly', 580),
#  ('cinematography', 579),
#  ('police', 579),
#  ('sound', 578),
#  ('type', 578),
#  ('whose', 578),
#  ('enjoyable', 573),
#  ('view', 573),
#  ('number', 572),
#  ('husband', 572),
#  ('daughter', 572),
#  ('romantic', 572),
#  ('documentary', 571),
#  ('self', 570),
#  ('robert', 569),
#  ('took', 569),
#  ('modern', 569),
#  ('superb', 569),
#  ('mean', 566),
#  ('shown', 563),
#  ('coming', 561),
#  ('important', 560),
#  ('king', 559),
#  ('leave', 559),
#  ('change', 558),
#  ('somewhat', 555),
#  ('wanted', 555),
#  ('tells', 554),
#  ('run', 552),
#  ('events', 552),
#  ('country', 552),
#  ('career', 552),
#  ('heard', 550),
#  ('season', 550),
#  ('girls', 549),
#  ('greatest', 549),
#  ('etc', 547),
#  ('care', 546),
#  ('starts', 545),
#  ('english', 542),
#  ('killer', 541),
#  ('animation', 540),
#  ('guys', 540),
#  ('totally', 540),
#  ('tale', 540),
#  ('usual', 539),
#  ('opinion', 535),
#  ('miss', 535),
#  ('easy', 531),
#  ('violence', 531),
#  ('songs', 530),
#  ('british', 528),
#  ('says', 526),
#  ('realistic', 525),
#  ('writing', 524),
#  ('act', 522),
#  ('writer', 522),
#  ('comic', 521),
#  ('thriller', 519),
#  ('television', 517),
#  ('power', 516),
#  ('ones', 515),
#  ('kid', 514),
#  ('novel', 513),
#  ('york', 513),
#  ('problem', 512),
#  ('alone', 512),
#  ('attention', 509),
#  ('involved', 508),
#  ('extremely', 507),
#  ('kill', 507),
#  ('seemed', 506),
#  ('hero', 505),
#  ('french', 505),
#  ('rock', 504),
#  ('stuff', 501),
#  ('wish', 499),
#  ('begins', 498),
#  ('taken', 497),
#  ('sad', 497),
#  ('ways', 496),
#  ('richard', 495),
#  ('knows', 494),
#  ('atmosphere', 493),
#  ('similar', 491),
#  ('car', 491),
#  ('taking', 491),
#  ('surprised', 491),
#  ('perfectly', 490),
#  ('george', 490),
#  ('across', 489),
#  ('team', 489),
#  ('eye', 489),
#  ('sequence', 489),
#  ('powerful', 488),
#  ('room', 488),
#  ('among', 488),
#  ('due', 488),
#  ('serious', 488),
#  ('b', 487),
#  ('cannot', 487),
#  ('strange', 487),
#  ('order', 487),
#  ('beauty', 486),
#  ('famous', 485),
#  ('herself', 484),
#  ('happened', 484),
#  ('myself', 484),
#  ('tries', 484),
#  ('class', 483),
#  ('four', 482),
#  ('cool', 481),
#  ('theme', 479),
#  ('anyway', 479),
#  ('release', 479),
#  ('opening', 478),
#  ('entertainment', 477),
#  ('unique', 475),
#  ('ends', 475),
#  ('slow', 475),
#  ('exactly', 475),
#  ('level', 474),
#  ('red', 474),
#  ('o', 474),
#  ('easily', 474),
#  ('interest', 472),
#  ('happen', 471),
#  ('crime', 470),
#  ('viewing', 468),
#  ('memorable', 467),
#  ('sets', 467),
#  ('group', 466),
#  ('stop', 466),
#  ('working', 463),
#  ('sister', 463),
#  ('message', 463),
#  ('problems', 463),
#  ('dance', 463),
#  ('knew', 462),
#  ('nature', 461),
#  ('mystery', 461),
#  ('bring', 460),
#  ('brought', 459),
#  ('thinking', 459),
#  ('believable', 459),
#  ('mostly', 458),
#  ('disney', 457),
#  ('couldn', 457),
#  ('society', 456),
#  ('lady', 455),
#  ('within', 455),
#  ('blood', 454),
#  ('parents', 453),
#  ('viewers', 453),
#  ('upon', 453),
#  ('meets', 452),
#  ('form', 452),
#  ('usually', 452),
#  ('peter', 452),
#  ('tom', 452),
#  ('soundtrack', 452),
#  ('local', 450),
#  ('follow', 448),
#  ('certain', 448),
#  ('whether', 447),
#  ('possible', 446),
#  ('emotional', 445),
#  ('above', 444),
#  ('de', 444),
#  ('killed', 444),
#  ('middle', 443),
#  ('god', 443),
#  ('needs', 442),
#  ('happens', 442),
#  ('flick', 442),
#  ('masterpiece', 441),
#  ('period', 440),
#  ('major', 440),
#  ('named', 439),
#  ('haven', 439),
#  ('th', 438),
#  ('particular', 438),
#  ('feature', 437),
#  ('earth', 437),
#  ('stand', 436),
#  ('typical', 435),
#  ('words', 435),
#  ('obviously', 433),
#  ('elements', 433),
#  ('romance', 431),
#  ('jane', 430),
#  ('showing', 427),
#  ('yourself', 427),
#  ('fantasy', 426),
#  ('brings', 426),
#  ('america', 423),
#  ('guess', 423),
#  ('huge', 422),
#  ('unfortunately', 422),
#  ('indeed', 421),
#  ('running', 421),
#  ('talent', 420),
#  ('stage', 419),
#  ('started', 418),
#  ('sweet', 417),
#  ('leads', 417),
#  ('japanese', 417),
#  ('poor', 416),
#  ('deal', 416),
#  ('personal', 413),
#  ('incredible', 413),
#  ('fast', 412),
#  ('deep', 410),
#  ('became', 410),
#  ('hours', 409),
#  ('giving', 408),
#  ('dream', 408),
#  ('nearly', 408),
#  ('turned', 407),
#  ('clearly', 407),
#  ('near', 406),
#  ('obvious', 406),
#  ('cut', 405),
#  ('surprise', 405),
#  ('era', 404),
#  ('body', 404),
#  ('hour', 403),
#  ('female', 403),
#  ('five', 403),
#  ('note', 399),
#  ('learn', 398),
#  ('truth', 398),
#  ('tony', 397),
#  ('feels', 397),
#  ('except', 397),
#  ('match', 397),
#  ('complete', 394),
#  ('clear', 394),
#  ('filmed', 394),
#  ('lots', 393),
#  ('keeps', 393),
#  ('older', 393),
#  ('street', 393),
#  ('eventually', 393),
#  ('buy', 392),
#  ('stewart', 391),
#  ('william', 391),
#  ('meet', 390),
#  ('joe', 390),
#  ('fall', 390),
#  ('talking', 389),
#  ('shots', 389),
#  ('difficult', 389),
#  ('rating', 389),
#  ('unlike', 389),
#  ('dramatic', 388),
#  ('means', 388),
#  ('situation', 386),
#  ('wonder', 386),
#  ('appears', 386),
#  ('subject', 386),
#  ('present', 386),
#  ('comments', 385),
#  ('lee', 383),
#  ('general', 383),
#  ('sequences', 383),
#  ('points', 382),
#  ('earlier', 382),
#  ('gone', 379),
#  ('check', 379),
#  ('suspense', 378),
#  ('ten', 378),
#  ('recommended', 378),
#  ('third', 377),
#  ('business', 377),
#  ('talk', 375),
#  ('leaves', 375),
#  ('beyond', 375),
#  ('portrayal', 374),
#  ('beautifully', 373),
#  ('bill', 372),
#  ('single', 372),
#  ('plenty', 371),
#  ('word', 371),
#  ('falls', 370),
#  ('whom', 370),
#  ('battle', 369),
#  ('non', 369),
#  ('figure', 369),
#  ('scary', 369),
#  ('using', 368),
#  ('return', 368),
#  ('add', 367),
#  ('doubt', 367),
#  ('success', 366),
#  ('hear', 366),
#  ('solid', 366),
#  ('jokes', 365),
#  ('touching', 365),
#  ('oh', 365),
#  ('political', 365),
#  ('awesome', 364),
#  ('hell', 364),
#  ('boys', 364),
#  ('sexual', 362),
#  ('recently', 362),
#  ('dog', 362),
#  ('straight', 361),
#  ('features', 361),
#  ('wouldn', 361),
#  ('please', 361),
#  ('setting', 360),
#  ('forget', 360),
#  ('lack', 360),
#  ('married', 359),
#  ('mark', 359),
#  ('social', 357),
#  ('adventure', 356),
#  ('interested', 356),
#  ('brothers', 355),
#  ('sees', 355),
#  ('actual', 355),
#  ('terrific', 355),
#  ('call', 354),
#  ('move', 354),
#  ('dr', 353),
#  ('theater', 353),
#  ('various', 353),
#  ('animated', 352),
#  ('western', 351),
#  ('baby', 350),
#  ('space', 350),
#  ('leading', 348),
#  ('disappointed', 348),
#  ('portrayed', 346),
#  ('aren', 346),
#  ('smith', 345),
#  ('screenplay', 345),
#  ('towards', 344),
#  ('hate', 344),
#  ('noir', 343),
#  ('decent', 342),
#  ('kelly', 342),
#  ('outstanding', 342),
#  ('journey', 341),
#  ('directors', 341),
#  ('effective', 340),
#  ('none', 340),
#  ('looked', 340),
#  ('sci', 339),
#  ('cold', 339),
#  ('fi', 339),
#  ('caught', 339),
#  ('mary', 339),
#  ('storyline', 339),
#  ('rich', 338),
#  ('charming', 338),
#  ('popular', 337),
#  ('rare', 337),
#  ('harry', 337),
#  ('manages', 337),
#  ('spirit', 336),
#  ('appreciate', 335),
#  ('open', 335),
#  ('acted', 334),
#  ('moves', 334),
#  ('basically', 334),
#  ('deserves', 333),
#  ('pace', 333),
#  ('century', 333),
#  ('subtle', 333),
#  ('boring', 333),
#  ('inside', 333),
#  ('mention', 333),
#  ('familiar', 332),
#  ('background', 332),
#  ('ben', 331),
#  ('supposed', 330),
#  ('creepy', 330),
#  ('secret', 329),
#  ('jim', 328),
#  ('die', 328),
#  ('effect', 327),
#  ('question', 327),
#  ('natural', 327),
#  ('impressive', 326),
#  ('language', 326),
#  ('rate', 326),
#  ('saying', 325),
#  ('intelligent', 325),
#  ('scott', 324),
#  ('realize', 324),
#  ('telling', 324),
#  ('material', 324),
#  ('singing', 323),
#  ('dancing', 322),
#  ('visual', 321),
#  ('imagine', 321),
#  ('adult', 321),
#  ('kept', 320),
#  ('office', 320),
#  ('uses', 319),
#  ('stunning', 318),
#  ('pure', 318),
#  ('wait', 318),
#  ('seriously', 317),
#  ('copy', 317),
#  ('previous', 317),
#  ('review', 317),
#  ('somehow', 316),
#  ('reading', 316),
#  ('create', 316),
#  ('magic', 316),
#  ('created', 316),
#  ('hot', 316),
#  ('stay', 315),
#  ('crazy', 315),
#  ('frank', 315),
#  ('escape', 315),
#  ('air', 315),
#  ('attempt', 315),
#  ('hands', 314),
#  ('filled', 313),
#  ('surprisingly', 312),
#  ('average', 312),
#  ('expected', 312),
#  ('complex', 311),
#  ('successful', 310),
#  ('studio', 310),
#  ('quickly', 310),
#  ('plus', 309),
#  ('male', 309),
#  ('co', 307),
#  ('minute', 306),
#  ('following', 306),
#  ('exciting', 306),
#  ('images', 306),
#  ('casting', 306),
#  ('e', 305),
#  ('reasons', 305),
#  ('german', 305),
#  ('members', 305),
#  ('themes', 305),
#  ('follows', 305),
#  ('touch', 304),
#  ('cute', 304),
#  ('free', 304),
#  ('edge', 304),
#  ('genius', 304),
#  ('outside', 303),
#  ('ok', 302),
#  ('admit', 302),
#  ('reviews', 302),
#  ('younger', 302),
#  ('master', 301),
#  ('fighting', 301),
#  ('odd', 301),
#  ('thanks', 300),
#  ('recent', 300),
#  ('comment', 300),
#  ('break', 300),
#  ('apart', 299),
#  ('begin', 298),
#  ('lovely', 298),
#  ('emotions', 298),
#  ('party', 297),
#  ('italian', 297),
#  ('doctor', 297),
#  ('sequel', 296),
#  ('missed', 296),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1673392),
#  ('the', 500102),
#  ('.', 494730),
#  ('a', 242330),
#  ('and', 238492),
#  ('of', 214873),
#  ('to', 204694),
#  ('is', 157411),
#  ('br', 154509),
#  ('it', 144679),
#  ('in', 137721),
#  ('i', 134503),
#  ('this', 116920),
#  ('that', 110860),
#  ('s', 96907),
#  ('was', 74499),
#  ('movie', 69004),
#  ('as', 67558),
#  ('for', 66270),
#  ('with', 65003),
#  ('but', 64384),
#  ('film', 59373),
#  ('t', 54442),
#  ('you', 51779),
#  ('on', 51392),
#  ('not', 46980),
#  ('are', 44053),
#  ('he', 43994),
#  ('have', 42875),
#  ('his', 41521),
#  ('be', 41498),
#  ('one', 39923),
#  ('all', 36014),
#  ('they', 35917),
#  ('at', 35792),
#  ('by', 33095),
#  ('so', 32080),
#  ('an', 31826),
#  ('like', 31514),
#  ('who', 31402),
#  ('from', 30229),
#  ('there', 29607),
#  ('just', 28390),
#  ('or', 28276),
#  ('about', 26435),
#  ('her', 26368),
#  ('if', 26321),
#  ('out', 26092),
#  ('what', 24581),
#  ('has', 24394),
#  ('some', 24053),
#  ('good', 22566),
#  ('can', 22307),
#  ('more', 20981),
#  ('when', 20908),
#  ('no', 20860),
#  ('she', 20667),
#  ('even', 20338),
#  ('up', 20261),
#  ('very', 19833),
#  ('would', 19472),
#  ('time', 18933),
#  ('only', 18699),
#  ('my', 18518),
#  ('really', 18000),
#  ('which', 17827),
#  ('had', 17432),
#  ('story', 17196),
#  ('see', 16930),
#  ('were', 16784),
#  ('bad', 16709),
#  ('their', 16663),
#  ('me', 16379),
#  ('we', 16187),
#  ('than', 15102),
#  ('well', 14913),
#  ('much', 14841),
#  ('do', 14413),
#  ('been', 14389),
#  ('get', 14346),
#  ('don', 14140),
#  ('people', 14091),
#  ('because', 14011),
#  ('into', 13678),
#  ('how', 13589),
#  ('other', 13468),
#  ('first', 13367),
#  ('will', 13204),
#  ('made', 12905),
#  ('then', 12880),
#  ('also', 12766),
#  ('make', 12747),
#  ('him', 12734),
#  ('most', 12702),
#  ('could', 12609),
#  ('any', 12318),
#  ('them', 12135),
#  ('way', 12014),
#  ('too', 12007),
#  ('its', 11932),
#  ('movies', 11746),
#  ('great', 11699),
#  ('after', 11476),
#  ('think', 10941),
#  ('characters', 10760),
#  ('plot', 10740),
#  ('acting', 10549),
#  ('character', 10526),
#  ('watch', 10524),
#  ('two', 10079),
#  ('being', 10003),
#  ('films', 9967),
#  ('seen', 9944),
#  ('did', 9802),
#  ('never', 9744),
#  ('over', 9649),
#  ('where', 9611),
#  ('off', 9597),
#  ('many', 9584),
#  ('little', 9533),
#  ('know', 9501),
#  ('ever', 9260),
#  ('show', 9156),
#  ('better', 9097),
#  ('life', 9057),
#  ('your', 8919),
#  ('does', 8811),
#  ('here', 8794),
#  ('why', 8781),
#  ('love', 8605),
#  ('end', 8604),
#  ('best', 8507),
#  ('man', 8492),
#  ('say', 8378),
#  ('scene', 8199),
#  ('these', 8142),
#  ('something', 8019),
#  ('m', 7998),
#  ('scenes', 7997),
#  ('ve', 7965),
#  ('should', 7961),
#  ('still', 7906),
#  ('go', 7874),
#  ('while', 7735),
#  ('such', 7678),
#  ('through', 7529),
#  ('back', 7395),
#  ('thing', 7394),
#  ('nothing', 7280),
#  ('watching', 7246),
#  ('doesn', 7137),
#  ('re', 7124),
#  ('didn', 6964),
#  ('actors', 6921),
#  ('those', 6909),
#  ('real', 6908),
#  ('director', 6850),
#  ('now', 6842),
#  ('old', 6741),
#  ('actually', 6688),
#  ('though', 6657),
#  ('funny', 6625),
#  ('another', 6583),
#  ('before', 6471),
#  ('going', 6421),
#  ('work', 6400),
#  ('look', 6394),
#  ('years', 6276),
#  ('few', 6234),
#  ('new', 6166),
#  ('same', 6134),
#  ('makes', 6018),
#  ('every', 6004),
#  ('find', 5992),
#  ('part', 5982),
#  ('lot', 5871),
#  ('again', 5856),
#  ('want', 5844),
#  ('pretty', 5779),
#  ('horror', 5741),
#  ('down', 5716),
#  ('seems', 5642),
#  ('around', 5560),
#  ('got', 5539),
#  ('things', 5527),
#  ('cast', 5521),
#  ('enough', 5449),
#  ('us', 5418),
#  ('fact', 5362),
#  ('original', 5359),
#  ('quite', 5335),
#  ('take', 5309),
#  ('however', 5275),
#  ('world', 5237),
#  ('thought', 5235),
#  ('long', 5212),
#  ('worst', 5212),
#  ('give', 5199),
#  ('big', 5139),
#  ('least', 5124),
#  ('script', 5102),
#  ('minutes', 5079),
#  ('point', 5069),
#  ('isn', 5026),
#  ('guy', 4999),
#  ('young', 4977),
#  ('right', 4938),
#  ('action', 4921),
#  ('gets', 4918),
#  ('without', 4861),
#  ('d', 4847),
#  ('whole', 4846),
#  ('anything', 4823),
#  ('come', 4784),
#  ('interesting', 4777),
#  ('may', 4777),
#  ('must', 4772),
#  ('between', 4764),
#  ('comedy', 4750),
#  ('almost', 4714),
#  ('own', 4682),
#  ('series', 4679),
#  ('making', 4655),
#  ('times', 4644),
#  ('saw', 4642),
#  ('done', 4606),
#  ('far', 4596),
#  ('might', 4576),
#  ('both', 4564),
#  ('ll', 4460),
#  ('role', 4411),
#  ('always', 4390),
#  ('family', 4372),
#  ('music', 4370),
#  ('bit', 4353),
#  ('am', 4337),
#  ('last', 4323),
#  ('kind', 4322),
#  ('girl', 4316),
#  ('feel', 4305),
#  ('since', 4295),
#  ('probably', 4286),
#  ('away', 4244),
#  ('tv', 4164),
#  ('woman', 4151),
#  ('rather', 4128),
#  ('sure', 4119),
#  ('anyone', 4050),
#  ('hard', 4042),
#  ('money', 3999),
#  ('trying', 3959),
#  ('yet', 3948),
#  ('looks', 3941),
#  ('believe', 3939),
#  ('looking', 3913),
#  ('day', 3878),
#  ('performance', 3864),
#  ('reason', 3857),
#  ('found', 3840),
#  ('someone', 3827),
#  ('having', 3826),
#  ('wasn', 3792),
#  ('maybe', 3745),
#  ('let', 3724),
#  ('comes', 3708),
#  ('fun', 3700),
#  ('goes', 3698),
#  ('book', 3698),
#  ('screen', 3681),
#  ('instead', 3668),
#  ('course', 3654),
#  ('put', 3644),
#  ('sense', 3632),
#  ('set', 3631),
#  ('played', 3605),
#  ('actor', 3573),
#  ('although', 3573),
#  ('our', 3566),
#  ('place', 3559),
#  ('effects', 3552),
#  ('ending', 3536),
#  ('each', 3530),
#  ('everything', 3522),
#  ('especially', 3498),
#  ('main', 3484),
#  ('half', 3435),
#  ('said', 3426),
#  ('year', 3425),
#  ('three', 3389),
#  ('watched', 3378),
#  ('poor', 3378),
#  ('audience', 3376),
#  ('dvd', 3366),
#  ('once', 3362),
#  ('idea', 3355),
#  ('worth', 3335),
#  ('seem', 3322),
#  ('left', 3294),
#  ('boring', 3289),
#  ('awful', 3282),
#  ('house', 3270),
#  ('different', 3260),
#  ('night', 3248),
#  ('play', 3231),
#  ('high', 3227),
#  ('everyone', 3225),
#  ('special', 3215),
#  ('american', 3208),
#  ('together', 3206),
#  ('else', 3199),
#  ('true', 3179),
#  ('shot', 3177),
#  ('shows', 3167),
#  ('version', 3146),
#  ('takes', 3142),
#  ('during', 3136),
#  ('stupid', 3129),
#  ('simply', 3095),
#  ('himself', 3088),
#  ('seeing', 3087),
#  ('wife', 3084),
#  ('job', 3084),
#  ('later', 3074),
#  ('black', 3073),
#  ('less', 3068),
#  ('john', 3066),
#  ('completely', 3057),
#  ('either', 3049),
#  ('plays', 3048),
#  ('read', 3046),
#  ('terrible', 3029),
#  ('star', 3017),
#  ('budget', 3015),
#  ('low', 2988),
#  ('mind', 2985),
#  ('wrong', 2978),
#  ('dead', 2978),
#  ('second', 2915),
#  ('nice', 2892),
#  ('line', 2886),
#  ('try', 2882),
#  ('used', 2848),
#  ('father', 2847),
#  ('camera', 2838),
#  ('kids', 2832),
#  ('death', 2829),
#  ('given', 2826),
#  ('rest', 2825),
#  ('waste', 2815),
#  ('fan', 2813),
#  ('help', 2801),
#  ('mean', 2800),
#  ('production', 2793),
#  ('war', 2792),
#  ('video', 2774),
#  ('women', 2774),
#  ('beautiful', 2772),
#  ('need', 2762),
#  ('hollywood', 2756),
#  ('use', 2744),
#  ('men', 2731),
#  ('sex', 2730),
#  ('home', 2725),
#  ('short', 2723),
#  ('worse', 2718),
#  ('supposed', 2702),
#  ('tell', 2677),
#  ('start', 2656),
#  ('top', 2633),
#  ('couple', 2620),
#  ('friends', 2601),
#  ('until', 2597),
#  ('next', 2575),
#  ('full', 2562),
#  ('along', 2561),
#  ('getting', 2540),
#  ('school', 2535),
#  ('oh', 2533),
#  ('doing', 2529),
#  ('couldn', 2529),
#  ('name', 2525),
#  ('stars', 2504),
#  ('perhaps', 2484),
#  ('dialogue', 2484),
#  ('understand', 2480),
#  ('enjoy', 2478),
#  ('lines', 2472),
#  ('truly', 2469),
#  ('classic', 2466),
#  ('excellent', 2459),
#  ('face', 2459),
#  ('came', 2453),
#  ('written', 2445),
#  ('won', 2443),
#  ('person', 2441),
#  ('head', 2439),
#  ('remember', 2430),
#  ('piece', 2421),
#  ('performances', 2405),
#  ('playing', 2399),
#  ('moments', 2397),
#  ('problem', 2388),
#  ('keep', 2371),
#  ('killer', 2369),
#  ('itself', 2366),
#  ('felt', 2362),
#  ('case', 2340),
#  ('recommend', 2337),
#  ('yes', 2333),
#  ('entire', 2330),
#  ('absolutely', 2327),
#  ('title', 2325),
#  ('sort', 2312),
#  ('small', 2306),
#  ('lost', 2297),
#  ('style', 2295),
#  ('episode', 2293),
#  ('unfortunately', 2284),
#  ('others', 2261),
#  ('went', 2260),
#  ('early', 2253),
#  ('finally', 2252),
#  ('horrible', 2247),
#  ('boy', 2245),
#  ('evil', 2233),
#  ('often', 2232),
#  ('called', 2229),
#  ('care', 2224),
#  ('seemed', 2220),
#  ('white', 2217),
#  ('guess', 2199),
#  ('human', 2191),
#  ('children', 2185),
#  ('become', 2170),
#  ('live', 2170),
#  ('laugh', 2163),
#  ('mother', 2151),
#  ('wanted', 2149),
#  ('already', 2143),
#  ('against', 2139),
#  ('picture', 2135),
#  ('direction', 2133),
#  ('gives', 2123),
#  ('hope', 2119),
#  ('definitely', 2117),
#  ('example', 2115),
#  ('liked', 2109),
#  ('certainly', 2098),
#  ('cinema', 2097),
#  ('writing', 2084),
#  ('based', 2081),
#  ('flick', 2074),
#  ('totally', 2074),
#  ('turn', 2070),
#  ('guys', 2066),
#  ('tries', 2064),
#  ('beginning', 2063),
#  ('sound', 2062),
#  ('mr', 2060),
#  ('several', 2056),
#  ('friend', 2053),
#  ('overall', 2046),
#  ('fans', 2045),
#  ('under', 2036),
#  ('entertaining', 2033),
#  ('becomes', 2031),
#  ('quality', 2002),
#  ('despite', 1999),
#  ('lead', 1990),
#  ('act', 1980),
#  ('god', 1973),
#  ('decent', 1972),
#  ('hour', 1971),
#  ('kill', 1961),
#  ('car', 1957),
#  ('perfect', 1954),
#  ('drama', 1949),
#  ('wonderful', 1944),
#  ('b', 1937),
#  ('crap', 1934),
#  ('dark', 1932),
#  ('child', 1927),
#  ('behind', 1925),
#  ('throughout', 1924),
#  ('close', 1921),
#  ('blood', 1918),
#  ('final', 1915),
#  ('hand', 1913),
#  ('wants', 1905),
#  ('son', 1903),
#  ('thinking', 1899),
#  ('starts', 1895),
#  ('obviously', 1893),
#  ('lives', 1892),
#  ('run', 1886),
#  ('kid', 1886),
#  ('humor', 1886),
#  ('girls', 1873),
#  ('etc', 1873),
#  ('except', 1863),
#  ('michael', 1861),
#  ('stuff', 1847),
#  ('gave', 1845),
#  ('art', 1844),
#  ('days', 1840),
#  ('history', 1840),
#  ('game', 1834),
#  ('side', 1833),
#  ('turns', 1828),
#  ('viewer', 1825),
#  ('town', 1818),
#  ('myself', 1810),
#  ('actress', 1807),
#  ('self', 1800),
#  ('gore', 1800),
#  ('eyes', 1793),
#  ('annoying', 1793),
#  ('able', 1792),
#  ('fine', 1791),
#  ('slow', 1789),
#  ('attempt', 1785),
#  ('past', 1782),
#  ('writer', 1782),
#  ('killed', 1778),
#  ('expect', 1772),
#  ('directed', 1772),
#  ('save', 1769),
#  ('loved', 1769),
#  ('genre', 1767),
#  ('themselves', 1760),
#  ('lack', 1756),
#  ('anyway', 1755),
#  ('ridiculous', 1755),
#  ('wouldn', 1747),
#  ('soon', 1744),
#  ('parts', 1737),
#  ('ok', 1734),
#  ('please', 1733),
#  ('obvious', 1726),
#  ('happens', 1720),
#  ('none', 1720),
#  ('fight', 1715),
#  ('works', 1710),
#  ('cannot', 1707),
#  ('daughter', 1704),
#  ('stop', 1702),
#  ('voice', 1697),
#  ('heart', 1697),
#  ('says', 1694),
#  ('late', 1692),
#  ('sometimes', 1690),
#  ('wonder', 1690),
#  ('seriously', 1685),
#  ('hell', 1682),
#  ('looked', 1680),
#  ('complete', 1674),
#  ('type', 1672),
#  ('heard', 1672),
#  ('feeling', 1671),
#  ('happened', 1668),
#  ('cut', 1665),
#  ('stories', 1664),
#  ('matter', 1656),
#  ('leave', 1653),
#  ('violence', 1653),
#  ('involved', 1646),
#  ('took', 1631),
#  ('extremely', 1631),
#  ('happen', 1617),
#  ('police', 1615),
#  ('enjoyed', 1613),
#  ('moment', 1612),
#  ('alone', 1610),
#  ('scary', 1607),
#  ('hero', 1605),
#  ('city', 1602),
#  ('group', 1602),
#  ('interest', 1594),
#  ('jokes', 1587),
#  ('cheap', 1583),
#  ('amazing', 1582),
#  ('particularly', 1576),
#  ('saying', 1567),
#  ('brother', 1566),
#  ('coming', 1563),
#  ('running', 1563),
#  ('apparently', 1558),
#  ('hours', 1557),
#  ('hit', 1555),
#  ('today', 1554),
#  ('possible', 1554),
#  ('yourself', 1551),
#  ('age', 1541),
#  ('body', 1536),
#  ('roles', 1533),
#  ('known', 1533),
#  ('told', 1523),
#  ('talking', 1521),
#  ('chance', 1517),
#  ('exactly', 1515),
#  ('living', 1514),
#  ('usually', 1510),
#  ('started', 1508),
#  ('shots', 1507),
#  ('favorite', 1502),
#  ('sad', 1495),
#  ('ends', 1493),
#  ('dull', 1493),
#  ('call', 1492),
#  ('silly', 1490),
#  ('serious', 1490),
#  ('female', 1489),
#  ('disappointed', 1486),
#  ('word', 1483),
#  ('predictable', 1482),
#  ('opening', 1480),
#  ('husband', 1480),
#  ('murder', 1480),
#  ('basically', 1478),
#  ('taken', 1477),
#  ('including', 1477),
#  ('experience', 1476),
#  ('rating', 1471),
#  ('james', 1471),
#  ('middle', 1469),
#  ('huge', 1468),
#  ('brilliant', 1466),
#  ('single', 1464),
#  ('five', 1463),
#  ('career', 1462),
#  ('cool', 1461),
#  ('ago', 1457),
#  ('across', 1453),
#  ('level', 1452),
#  ('talent', 1446),
#  ('turned', 1443),
#  ('score', 1440),
#  ('number', 1440),
#  ('non', 1429),
#  ('strong', 1428),
#  ('english', 1428),
#  ('king', 1427),
#  ('aren', 1426),
#  ('shown', 1425),
#  ('highly', 1425),
#  ('mostly', 1422),
#  ('taking', 1419),
#  ('earth', 1419),
#  ('avoid', 1417),
#  ('song', 1417),
#  ('wish', 1415),
#  ('major', 1414),
#  ('order', 1411),
#  ('bunch', 1403),
#  ('novel', 1401),
#  ('room', 1400),
#  ('david', 1395),
#  ('whose', 1394),
#  ('lame', 1394),
#  ('clearly', 1391),
#  ('cinematography', 1391),
#  ('usual', 1391),
#  ('ones', 1389),
#  ('released', 1386),
#  ('review', 1385),
#  ('opinion', 1383),
#  ('fast', 1382),
#  ('power', 1378),
#  ('somewhat', 1377),
#  ('reality', 1369),
#  ('straight', 1367),
#  ('strange', 1367),
#  ('change', 1364),
#  ('musical', 1359),
#  ('poorly', 1358),
#  ('light', 1358),
#  ('beyond', 1357),
#  ('view', 1355),
#  ('simple', 1350),
#  ('sequel', 1340),
#  ('four', 1340),
#  ('hilarious', 1339),
#  ('sorry', 1336),
#  ('documentary', 1335),
#  ('knew', 1334),
#  ('robert', 1333),
#  ('words', 1333),
#  ('falls', 1332),
#  ('happy', 1331),
#  ('due', 1330),
#  ('effort', 1325),
#  ('country', 1316),
#  ('problems', 1311),
#  ('easily', 1310),
#  ('talk', 1309),
#  ('knows', 1308),
#  ('finds', 1305),
#  ('local', 1304),
#  ('theater', 1303),
#  ('class', 1303),
#  ('important', 1302),
#  ('attention', 1301),
#  ('appears', 1296),
#  ('weak', 1295),
#  ('television', 1289),
#  ('modern', 1289),
#  ('mention', 1289),
#  ('tried', 1288),
#  ('songs', 1286),
#  ('entertainment', 1281),
#  ('comic', 1281),
#  ('ten', 1278),
#  ('bring', 1278),
#  ('relationship', 1275),
#  ('thriller', 1275),
#  ('minute', 1272),
#  ('giving', 1270),
#  ('events', 1270),
#  ('storyline', 1269),
#  ('british', 1268),
#  ('editing', 1268),
#  ('dialog', 1267),
#  ('whether', 1265),
#  ('upon', 1265),
#  ('sequence', 1261),
#  ('die', 1260),
#  ('stay', 1259),
#  ('add', 1253),
#  ('zombie', 1250),
#  ('rock', 1246),
#  ('lee', 1245),
#  ('o', 1244),
#  ('points', 1242),
#  ('near', 1242),
#  ('lady', 1241),
#  ('needs', 1240),
#  ('jack', 1240),
#  ('mystery', 1239),
#  ('george', 1238),
#  ('sets', 1237),
#  ('using', 1234),
#  ('hate', 1232),
#  ('actual', 1231),
#  ('miss', 1229),
#  ('badly', 1228),
#  ('feels', 1223),
#  ('nearly', 1222),
#  ('episodes', 1221),
#  ('similar', 1213),
#  ('eye', 1213),
#  ('unless', 1211),
#  ('within', 1209),
#  ('tells', 1208),
#  ('future', 1205),
#  ('rent', 1203),
#  ('okay', 1201),
#  ('lots', 1199),
#  ('somehow', 1198),
#  ('material', 1198),
#  ('premise', 1197),
#  ('richard', 1197),
#  ('paul', 1196),
#  ('message', 1195),
#  ('above', 1194),
#  ('stand', 1194),
#  ('whatever', 1192),
#  ('supporting', 1188),
#  ('mess', 1182),
#  ('kept', 1180),
#  ('haven', 1179),
#  ('clear', 1178),
#  ('sister', 1173),
#  ('comments', 1173),
#  ('red', 1162),
#  ('named', 1161),
#  ('space', 1160),
#  ('sit', 1160),
#  ('team', 1159),
#  ('check', 1159),
#  ('theme', 1153),
#  ('imagine', 1151),
#  ('fall', 1150),
#  ('figure', 1147),
#  ('doubt', 1147),
#  ('feature', 1145),
#  ('general', 1145),
#  ('romantic', 1140),
#  ('possibly', 1139),
#  ('imdb', 1138),
#  ('herself', 1136),
#  ('buy', 1136),
#  ('release', 1135),
#  ('means', 1134),
#  ('filmed', 1134),
#  ('reviews', 1134),
#  ('elements', 1133),
#  ('killing', 1131),
#  ('gone', 1129),
#  ('average', 1128),
#  ('follow', 1126),
#  ('working', 1125),
#  ('write', 1125),
#  ('decided', 1124),
#  ('showing', 1123),
#  ('typical', 1121),
#  ('wait', 1120),
#  ('viewers', 1119),
#  ('tom', 1116),
#  ('surprised', 1113),
#  ('animation', 1112),
#  ('ways', 1112),
#  ('enjoyable', 1111),
#  ('joke', 1108),
#  ('moving', 1108),
#  ('york', 1107),
#  ('suspense', 1104),
#  ('monster', 1103),
#  ('hear', 1102),
#  ('third', 1099),
#  ('move', 1098),
#  ('expected', 1096),
#  ('dumb', 1096),
#  ('begins', 1094),
#  ('period', 1094),
#  ('oscar', 1094),
#  ('free', 1090),
#  ('nor', 1088),
#  ('fails', 1087),
#  ('peter', 1084),
#  ('writers', 1082),
#  ('certain', 1082),
#  ('leads', 1081),
#  ('otherwise', 1079),
#  ('form', 1078),
#  ('credits', 1077),
#  ('among', 1076),
#  ('soundtrack', 1076),
#  ('forget', 1076),
#  ('needed', 1075),
#  ('parents', 1073),
#  ('easy', 1073),
#  ('french', 1073),
#  ('sequences', 1071),
#  ('shame', 1069),
#  ('total', 1069),
#  ('sexual', 1066),
#  ('famous', 1059),
#  ('begin', 1058),
#  ('hot', 1056),
#  ('reading', 1054),
#  ('th', 1052),
#  ('disney', 1051),
#  ('dr', 1047),
#  ('eventually', 1047),
#  ('screenplay', 1045),
#  ('crime', 1044),
#  ('wasted', 1043),
#  ('question', 1043),
#  ('learn', 1042),
#  ('cheesy', 1040),
#  ('forced', 1040),
#  ('tale', 1038),
#  ('note', 1035),
#  ('baby', 1034),
#  ('america', 1033),
#  ('development', 1032),
#  ('subject', 1032),
#  ('viewing', 1032),
#  ('weird', 1031),
#  ('footage', 1030),
#  ('ask', 1029),
#  ('surprise', 1025),
#  ('dance', 1025),
#  ('indeed', 1023),
#  ('male', 1023),
#  ('forward', 1022),
#  ('laughs', 1022),
#  ('particular', 1022),
#  ('nudity', 1021),
#  ('sounds', 1018),
#  ('deal', 1018),
#  ('directing', 1016),
#  ('brought', 1015),
#  ('japanese', 1015),
#  ('de', 1014),
#  ('dog', 1014),
#  ('directors', 1011),
#  ('stage', 1009),
#  ('comment', 1006),
#  ('street', 1005),
#  ('box', 1003),
#  ('truth', 1002),
#  ('difficult', 1001),
#  ('crazy', 999),
#  ('incredibly', 996),
#  ('potential', 996),
#  ('season', 996),
#  ('flat', 995),
#  ('open', 995),
#  ('joe', 992),
#  ('leaves', 991),
#  ('realistic', 991),
#  ('girlfriend', 990),
#  ('hardly', 989),
#  ('cop', 987),
#  ('acted', 986),
#  ('gay', 985),
#  ('result', 985),
#  ('realize', 984),
#  ('became', 984),
#  ('fi', 983),
#  ('plus', 981),
#  ('plain', 979),
#  ('sci', 977),
#  ('atmosphere', 977),
#  ('pay', 976),
#  ('worked', 975),
#  ('pointless', 970),
#  ('fire', 970),
#  ('christmas', 970),
#  ('quickly', 968),
#  ('air', 963),
#  ('believable', 963),
#  ('remake', 962),
#  ('nature', 957),
#  ('romance', 957),
#  ('meant', 956),
#  ('appear', 956),
#  ('situation', 952),
#  ('doctor', 951),
#  ('hands', 950),
#  ('apart', 947),
#  ('meet', 946),
#  ('dramatic', 946),
#  ('interested', 946),
#  ('creepy', 946),
#  ('earlier', 944),
#  ('previous', 943),
#  ('twist', 942),
#  ('fantastic', 941),
#  ('greatest', 941),
#  ('admit', 940),
#  ('casting', 940),
#  ('e', 939),
#  ('effect', 939),
#  ('ideas', 937),
#  ('sadly', 937),
#  ('attempts', 934),
#  ('villain', 931),
#  ('mark', 931),
#  ('towards', 930),
#  ('spoilers', 926),
#  ('rate', 926),
#  ('break', 926),
#  ('zombies', 924),
#  ('bored', 923),
#  ('features', 923),
#  ('whom', 920),
#  ('older', 919),
#  ('dream', 918),
#  ('filmmakers', 914),
#  ('fighting', 913),
#  ('list', 912),
#  ('missing', 909),
#  ('setting', 908),
#  ('create', 908),
#  ('front', 906),
#  ('background', 906),
#  ('wrote', 905),
#  ('telling', 904),
#  ('ben', 903),
#  ('meets', 902),
#  ('expecting', 899),
#  ('co', 897),
#  ('leading', 896),
#  ('society', 896),
#  ('gun', 894),
#  ('deep', 894),
#  ('secret', 893),
#  ('plenty', 893),
#  ('outside', 893),
#  ('bill', 892),
#  ('spent', 892),
#  ('keeps', 891),
#  ('neither', 888),
#  ('reasons', 887),
#  ('fairly', 884),
#  ('jane', 884),
#  ('trash', 883),
#  ('c', 881),
#  ('talented', 878),
#  ('return', 878),
#  ('pathetic', 875),
#  ('business', 873),
#  ('boys', 872),
#  ('cover', 871),
#  ('fantasy', 870),
#  ('emotional', 869),
#  ('inside', 867),
#  ('island', 866),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times

for term, cnt in list(total_counts.most_common()):
    if cnt > 10:
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term] + 1)
        pos_neg_ratios[term] = pos_neg_ratio
        
for word, ratio in pos_neg_ratio.most_common():
    if ratio > 1:
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / ratio+0.01))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f5abf91e7c2a> in <module>()
#      10         pos_neg_ratios[term] = pos_neg_ratio
#      11
# ---> 12 for word, ratio in pos_neg_ratio.most_common():
#      13     if ratio > 1:
#      14         pos_neg_ratios[word] = np.log(ratio)
#
# AttributeError: 'float' object has no attribute 'most_common'

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'fawn': 1,
#  'tsukino': 2,
#  'saimin': 35970,
#  'nunnery': 4,
#  'deferment': 5,
#  'sonja': 6,
#  'tilton': 8,
#  'vani': 48362,
#  'woods': 10,
#  'spiders': 11,
#  'bedknob': 12,
#  'hanging': 71,
#  'woody': 14,
#  'trawling': 15,
#  'fopish': 16,
#  'comically': 17,
#  'localized': 18,
#  'sevens': 19,
#  'disobeying': 20,
#  'yougoslavia': 21,
#  'gad': 48363,
#  'canet': 23,
#  'scola': 24,
#  'acurately': 25,
#  'scold': 26,
#  'gteborg': 27,
#  'originality': 29,
#  'grindhouses': 56014,
#  'enchelada': 170,
#  'gaa': 48366,
#  'hermann': 32,
#  'workaday': 58270,
#  'rumbustious': 33,
#  'benvolio': 34,
#  'familiarness': 35,
#  'hahahah': 67696,
#  'wracked': 37,
#  'diehard': 54199,
#  'gandolphini': 39,
#  'donger': 40,
#  'eugenics': 41,
#  'dongen': 42,
#  'appropriation': 43,
#  'transvestism': 44,
#  'taj': 73069,
#  'llbean': 43111,
#  'strictest': 46,
#  'screaming': 47,
#  'seamier': 48,
#  'bendan': 49,
#  'revelers': 35976,
#  'wooded': 51,
#  'spacy': 23768,
#  'liaisons': 53,
#  'grueling': 54,
#  'broiler': 55,
#  'wooden': 56,
#  'nightingale': 70788,
#  'bucatinsky': 57,
#  'tambin': 58,
#  'broiled': 59,
#  'altagracia': 60,
#  'circuitry': 61,
#  'tak': 73070,
#  'crotch': 62,
#  'stereotypical': 63,
#  'busybody': 23770,
#  'burgade': 66,
#  'spoilerish': 67,
#  'thrace': 68,
#  'gaskets': 69,
#  'tuaregs': 55021,
#  'snuggles': 70,
#  'francesco': 13,
#  'scrapes': 72,
#  'feasibility': 73,
#  'miniatures': 74,
#  'snuggest': 75,
#  'byner': 61003,
#  'zaniacs': 76,
#  'sustaining': 78,
#  'consenting': 79,
#  'scraped': 80,
#  'snuggled': 81,
#  'inanimate': 82,
#  'uality': 83,
#  'ghostie': 48374,
#  'rewritten': 65631,
#  'errors': 85,
#  'dialogs': 86,
#  'reopens': 87,
#  'cooking': 89,
#  'fonzie': 91,
#  'opportunists': 70767,
#  'warmongering': 92,
#  'dicovered': 93,
#  'shocky': 94,
#  'videodrome': 95,
#  'designing': 96,
#  'pawed': 97,
#  'hallucinating': 98,
#  'succumb': 99,
#  'shocks': 100,
#  'demotes': 35984,
#  'gatt': 69367,
#  'crouch': 103,
#  'chins': 104,
#  'rocque': 105,
#  'mailings': 106,
#  'brainwashed': 107,
#  'nickolodean': 26116,
#  'mcanally': 108,
#  'ching': 109,
#  'perfunctorily': 110,
#  'china': 111,
#  'kurupt': 112,
#  'affiliated': 114,
#  'babaganoosh': 115,
#  'shiktak': 116,
#  'wiseguy': 117,
#  'natured': 118,
#  'fidgetting': 119,
#  'kids': 121,
#  'uplifting': 122,
#  'addario': 123,
#  'climbed': 125,
#  'controversy': 127,
#  'kida': 128,
#  'kidd': 129,
#  'natures': 131,
#  'neurologist': 132,
#  'spotty': 133,
#  'climber': 134,
#  'golden': 136,
#  'cobblers': 137,
#  'projection': 138,
#  'lengthed': 139,
#  'fastforwarding': 140,
#  'sters': 141,
#  'lengthen': 142,
#  'bocka': 143,
#  'etherything': 144,
#  'darkon': 145,
#  'bumblebum': 147,
#  'unsinkable': 148,
#  'stern': 149,
#  'unearned': 150,
#  'sneha': 151,
#  'sentimental': 62858,
#  'disproportionately': 66843,
#  'dnd': 153,
#  'sternest': 154,
#  'dna': 155,
#  'zenderland': 156,
#  'catchy': 158,
#  'insecurity': 159,
#  'grahame': 161,
#  'cannibal': 162,
#  'sidebars': 163,
#  'hoggish': 48387,
#  'butterface': 165,
#  'music': 166,
#  'therefore': 167,
#  'renuka': 168,
#  'distortions': 169,
#  'mutinies': 30,
#  'sermons': 171,
#  'pinpoints': 172,
#  'boobage': 173,
#  'populations': 174,
#  'watercolor': 73484,
#  'mesmerize': 175,
#  'quinnell': 176,
#  'yahoo': 177,
#  'faceted': 178,
#  'gijn': 179,
#  'rickman': 180,
#  'exce': 181,
#  'boorman': 183,
#  'foregrounds': 184,
#  'primeval': 185,
#  'schoolboys': 186,
#  'voicework': 187,
#  'blustering': 1141,
#  'intake': 189,
#  'morally': 190,
#  'locked': 1166,
#  'kampala': 192,
#  'jeffries': 62897,
#  'jumbling': 193,
#  'lomax': 194,
#  'locken': 195,
#  'nickson': 23795,
#  'locker': 197,
#  'gershon': 198,
#  'ludicrosity': 199,
#  'matilde': 200,
#  'coprophilia': 201,
#  'expressively': 202,
#  'unreconstructed': 203,
#  'wana': 204,
#  'wang': 205,
#  'wand': 206,
#  'wane': 1284,
#  'unjust': 208,
#  'edgeways': 211,
#  'titanium': 212,
#  'muscical': 53227,
#  'pinta': 213,
#  'want': 214,
#  'cookers': 215,
#  'kakka': 73751,
#  'pinto': 216,
#  'cookery': 217,
#  'absolute': 218,
#  'ghoultown': 219,
#  'whoopdedoodles': 220,
#  'promting': 64832,
#  'tchaikovsky': 221,
#  'travel': 222,
#  'subtleness': 223,
#  'copious': 224,
#  'busco': 225,
#  'propane': 36006,
#  'playback': 227,
#  'dangerfield': 228,
#  'saskatchewan': 24305,
#  'cadence': 232,
#  'tabac': 36722,
#  'barbra': 234,
#  'uselessness': 235,
#  'assimilated': 236,
#  'highsmith': 237,
#  'minny': 40119,
#  'exult': 73406,
#  'defintly': 36009,
#  'dinosaurs': 240,
#  'wrong': 241,
#  'seda': 242,
#  'stollen': 243,
#  'twined': 244,
#  'sentencing': 245,
#  'ouroboros': 247,
#  'assimilates': 248,
#  'tsukurou': 56582,
#  'colorfully': 249,
#  'sissorhands': 250,
#  'glenne': 251,
#  'comatose': 68734,
#  'subplots': 253,
#  'sickening': 254,
#  'tulip': 255,
#  'perpetrator': 257,
#  'chandon': 258,
#  'quiting': 36014,
#  'footraces': 261,
#  'nonsensical': 262,
#  'romper': 263,
#  'rawhide': 264,
#  'dolemite': 265,
#  'snugly': 266,
#  'kuei': 267,
#  'lahm': 60231,
#  'welcomed': 268,
#  'concurrence': 269,
#  'puling': 270,
#  'patricide': 271,
#  'stoicism': 272,
#  'whizzing': 273,
#  'partnered': 274,
#  'sidekicks': 275,
#  'externalize': 48408,
#  'incoherences': 277,
#  'shears': 61038,
#  'rewarded': 278,
#  'hellishly': 279,
#  'aargh': 280,
#  'playhouse': 281,
#  'wickedly': 283,
#  'fit': 284,
#  'labratory': 285,
#  'lifeline': 286,
#  'bringing': 287,
#  'gridiron': 288,
#  'striking': 23810,
#  'uriah': 290,
#  'cineliterate': 291,
#  'secede': 292,
#  'cronicles': 72900,
#  'agekudos': 293,
#  'applecart': 65744,
#  'fia': 294,
#  'fig': 295,
#  'fmvs': 296,
#  'fie': 297,
#  'wales': 298,
#  'tsiang': 299,
#  'stensvold': 300,
#  'fin': 301,
#  'doctresses': 302,
#  'fil': 303,
#  'fim': 304,
#  'zucker': 305,
#  'corridor': 306,
#  'sinuously': 307,
#  'paterfamilias': 308,
#  'songwriter': 309,
#  'lateesha': 310,
#  'riggers': 313,
#  'unisten': 314,
#  'zac': 61045,
#  'shivam': 315,
#  'twits': 316,
#  'recollections': 36023,
#  'effects': 319,
#  'bravora': 320,
#  'multidimensional': 321,
#  'sixteen': 322,
#  'undeveloped': 323,
#  'cadillacs': 29121,
#  'saddened': 324,
#  'simialr': 325,
#  'sommerset': 326,
#  'interwhined': 327,
#  'defecate': 328,
#  'whacking': 329,
#  'bartok': 330,
#  'barton': 331,
#  'arron': 332,
#  'arros': 333,
#  'frewer': 334,
#  'arrow': 335,
#  'ingrid': 336,
#  'stribor': 337,
#  'burial': 339,
#  'approporiately': 340,
#  'telescope': 341,
#  'wobblyhand': 342,
#  'examplewhen': 48419,
#  'tantalisingly': 343,
#  'knoller': 36029,
#  'allah': 346,
#  'allan': 347,
#  'phoenicians': 348,
#  'parasites': 349,
#  'childen': 17588,
#  'krimis': 72272,
#  'metafiction': 352,
#  'zat': 61054,
#  'golem': 356,
#  'melida': 358,
#  'antiheroes': 359,
#  'oprah': 360,
#  'smirk': 361,
#  'protray': 362,
#  'indiscretion': 363,
#  'brutish': 36031,
#  'mason': 365,
#  'brittannica': 366,
#  'encourage': 367,
#  'ahlstedt': 56825,
#  'adapt': 368,
#  'esoterics': 369,
#  'constants': 36226,
#  'guitarists': 23824,
#  'outburst': 372,
#  'instigators': 53969,
#  'bergqvist': 23825,
#  'abbott': 374,
#  'stamping': 375,
#  'abbots': 376,
#  'breen': 23826,
#  'strate': 378,
#  'underfoot': 379,
#  'strata': 380,
#  'magickal': 381,
#  'mattter': 382,
#  'pumpkins': 384,
#  'corrects': 385,
#  'stuntpeople': 386,
#  'drssing': 387,
#  'cinnderella': 23828,
#  'estimate': 389,
#  'ugghhh': 390,
#  'gameplay': 391,
#  'universally': 392,
#  'jugs': 23829,
#  'reiser': 48429,
#  'competes': 395,
#  'drohkaal': 396,
#  'sickeningly': 397,
#  'chiara': 398,
#  'disturbed': 401,
#  'competed': 402,
#  'dentures': 403,
#  'portmanteau': 404,
#  'ineffectively': 405,
#  'loudness': 406,
#  'guardsmen': 407,
#  'yester': 408,
#  'teleseries': 48433,
#  'lazers': 410,
#  'lightened': 23834,
#  'deforce': 412,
#  'dawns': 61064,
#  'disfigured': 415,
#  'humanitarians': 416,
#  'maladies': 417,
#  'tentpoles': 23836,
#  'sandro': 72180,
#  'stylistics': 419,
#  'kfc': 420,
#  'sssr': 62126,
#  'hicock': 421,
#  'dupuis': 422,
#  'disfigures': 423,
#  'sooty': 424,
#  'boerner': 425,
#  'spiderbabe': 426,
#  'olds': 427,
#  'bakelite': 428,
#  'renovated': 429,
#  'service': 430,
#  'forrester': 431,
#  'hemmitt': 42322,
#  'reuben': 434,
#  'needed': 436,
#  'smight': 437,
#  'master': 438,
#  'teen': 57238,
#  'seeber': 439,
#  'critter': 440,
#  'hiya': 441,
#  'fuzziness': 442,
#  'genesis': 443,
#  'rewards': 444,
#  'tomiche': 23841,
#  'enthrall': 447,
#  'noll': 48443,
#  'splendiferous': 449,
#  'organically': 450,
#  'popkin': 451,
#  'swish': 19363,
#  'mutilated': 453,
#  'wookies': 70645,
#  'fatherlands': 454,
#  'noli': 23877,
#  'horrible': 26370,
#  'positively': 457,
#  'smothers': 458,
#  'templarios': 459,
#  'ahmed': 460,
#  'maglev': 461,
#  'descas': 462,
#  'bannister': 463,
#  'anniversaries': 464,
#  'shayan': 465,
#  'fyall': 466,
#  'idly': 467,
#  'tuska': 61069,
#  'boogeyboarded': 468,
#  'idle': 469,
#  'exclaimed': 470,
#  'sheen': 23845,
#  'bassenger': 62702,
#  'twinkies': 56364,
#  'feeling': 473,
#  'nobudget': 474,
#  'certificate': 72329,
#  'thas': 61071,
#  'dozes': 476,
#  'assertiveness': 477,
#  'dolan': 23848,
#  'longs': 480,
#  'redesigned': 48453,
#  'spectrum': 482,
#  'condsidering': 23849,
#  'longo': 484,
#  'dozed': 485,
#  'mishra': 486,
#  'arousal': 487,
#  'pomp': 61075,
#  'deamon': 489,
#  'urinate': 490,
#  'fuing': 74023,
#  'protags': 491,
#  'dozen': 493,
#  'farnham': 494,
#  'affairs': 495,
#  'wholesome': 496,
#  'courier': 23851,
#  'hymen': 498,
#  'achievement': 72183,
#  'paramedics': 499,
#  'uncouth': 500,
#  'filmette': 501,
#  'racers': 502,
#  'comandante': 61079,
#  'toothed': 504,
#  'quinton': 505,
#  'unpersons': 506,
#  'heavyarms': 507,
#  'britches': 508,
#  'affaire': 509,
#  'coulisses': 510,
#  'workmates': 511,
#  'xine': 71383,
#  'kremlin': 512,
#  'concedes': 514,
#  'pixilated': 515,
#  'witney': 516,
#  'inoue': 67785,
#  'committing': 517,
#  'limitless': 518,
#  'diminishing': 519,
#  'vexing': 520,
#  'cinematic': 521,
#  'resonates': 522,
#  'disjointed': 523,
#  'tensely': 524,
#  'mouth': 525,
#  'reverence': 526,
#  'conceded': 527,
#  'resonated': 528,
#  'dailey': 529,
#  'bradford': 530,
#  'treize': 531,
#  'singer': 532,
#  'majo': 533,
#  'kiya': 534,
#  'woolnough': 535,
#  'majd': 536,
#  'dorama': 538,
#  'tech': 539,
#  'psst': 48465,
#  'teck': 541,
#  'ahlan': 542,
#  'ferhan': 543,
#  'scream': 545,
#  'saying': 546,
#  'interpretaion': 547,
#  'franklyn': 548,
#  'dickey': 549,
#  'thad': 61088,
#  'dicker': 551,
#  'gillham': 552,
#  'padded': 553,
#  'locationed': 23865,
#  'independentcritics': 555,
#  'king': 14579,
#  'tempted': 556,
#  'cheaply': 557,
#  'hypercube': 558,
#  'eliminated': 559,
#  'hounded': 560,
#  'orleans': 561,
#  'flowers': 61091,
#  'clicked': 563,
#  'qestions': 564,
#  'rosenstrae': 565,
#  'dialoge': 566,
#  'luby': 567,
#  'yakusho': 38607,
#  'rico': 568,
#  'lube': 569,
#  'girlshilarious': 570,
#  'bliss': 571,
#  'rick': 572,
#  'rich': 573,
#  'venal': 69753,
#  'usenet': 574,
#  'rice': 575,
#  'ranma': 577,
#  'plate': 578,
#  'remotest': 579,
#  'plata': 580,
#  'sturgess': 581,
#  'waaaaaay': 583,
#  'plato': 584,
#  'plath': 585,
#  'umbilical': 586,
#  'traumatising': 587,
#  'platt': 589,
#  'guileful': 590,
#  'mcnab': 591,
#  'litghow': 63665,
#  'sciorra': 592,
#  'altogether': 593,
#  'toungue': 594,
#  'massacring': 23872,
#  'bicenntinial': 596,
#  'disses': 23873,
#  'droning': 598,
#  'levered': 48475,
#  'stoically': 600,
#  'jaguar': 601,
#  'policial': 602,
#  'traction': 61066,
#  'rectal': 603,
#  'nicely': 604,
#  'boarder': 605,
#  'pretzel': 606,
#  'patch': 607,
#  'eyelids': 608,
#  'jokerish': 48477,
#  'rehibilitation': 610,
#  'chambara': 611,
#  'juvenilia': 612,
#  'boarded': 613,
#  'larcenist': 614,
#  'goomba': 615,
#  'cull': 36078,
#  'bluray': 70664,
#  'uncomfirmed': 618,
#  'shrewdly': 619,
#  'janikowski': 620,
#  'heirloom': 621,
#  'clarified': 622,
#  'sensitivity': 623,
#  'howse': 624,
#  'woof': 70999,
#  'fragglerock': 23878,
#  'headless': 62992,
#  'erika': 629,
#  'eriko': 630,
#  'pinoy': 631,
#  'legions': 49777,
#  'edgiest': 632,
#  'clarifies': 633,
#  'advisedly': 634,
#  'playfulness': 635,
#  'descours': 636,
#  'maricarmen': 61107,
#  'lots': 638,
#  'lotr': 639,
#  'thuggee': 72262,
#  'irs': 640,
#  'droves': 641,
#  'xvi': 642,
#  'irk': 17879,
#  'irl': 644,
#  'paxinou': 645,
#  'cule': 36079,
#  'ira': 647,
#  'belzer': 648,
#  'irc': 649,
#  'ire': 650,
#  'pixardreamworks': 651,
#  'discipline': 26498,
#  'lyoko': 653,
#  'extend': 654,
#  'nature': 655,
#  'transcendant': 27605,
#  'lapping': 659,
#  'impalements': 48484,
#  'dinedash': 661,
#  'moviehowever': 68262,
#  'extent': 663,
#  'accessed': 61112,
#  'tendons': 665,
#  'bisleri': 666,
#  'tyranny': 667,
#  'brilliantness': 668,
#  'powells': 73508,
#  'boardman': 669,
#  'veer': 670,
#  'voyeuristic': 671,
#  'himalayas': 672,
#  'lookit': 674,
#  'heating': 675,
#  'incense': 676,
#  'levitating': 677,
#  'dimanche': 61740,
#  'lookin': 678,
#  'himalayan': 679,
#  'veen': 680,
#  'southeastern': 681,
#  'moravia': 682,
#  'eradicate': 683,
#  'rehash': 684,
#  'mortified': 685,
#  'fondles': 686,
#  'tmnt': 687,
#  'giardello': 68949,
#  'blonds': 689,
#  'gopher': 690,
#  'wearying': 691,
#  'gypsies': 692,
#  'haggerty': 693,
#  'puposelessly': 694,
#  'basque': 695,
#  'decapitates': 23893,
#  'humming': 697,
#  'medioacre': 699,
#  'smackdown': 700,
#  'byrnes': 71699,
#  'underdone': 703,
#  'righteousness': 63629,
#  'milquetoast': 704,
#  'triviality': 706,
#  'union': 707,
#  'sauraus': 708,
#  'fro': 710,
#  'kojak': 711,
#  '.': 712,
#  'bothers': 713,
#  'much': 714,
#  'muco': 715,
#  'chink': 716,
#  'destructible': 717,
#  'progenitor': 718,
#  'unleavened': 719,
#  'fry': 720,
#  'tallest': 721,
#  'tutoyer': 4389,
#  'toning': 724,
#  'obese': 725,
#  'sensationalized': 726,
#  'toyko': 61123,
#  'spiv': 728,
#  'retrospect': 729,
#  'spit': 730,
#  'arkin': 731,
#  'charleton': 732,
#  'davy': 733,
#  'jeon': 734,
#  'circumcision': 48498,
#  'dave': 736,
#  'elivra': 61111,
#  'phlox': 737,
#  'doubts': 738,
#  'stepdad': 739,
#  'spin': 740,
#  'skilfully': 4495,
#  'wildcat': 742,
#  'noland': 743,
#  'unecessary': 23902,
#  'misconstrues': 746,
#  'alatri': 747,
#  'unwillingness': 36096,
#  'professionally': 4545,
#  'employ': 750,
#  'flatlands': 36097,
#  'misconstrued': 752,
#  'rescinds': 753,
#  'unaffecting': 64549,
#  'genuingly': 62051,
#  'prostrate': 756,
#  'predated': 65807,
#  'elaborate': 36099,
#  'belittling': 758,
#  'shirow': 759,
#  'shirou': 760,
#  'parekh': 761,
#  'godzirra': 762,
#  'ephemerality': 763,
#  'majin': 764,
#  'ditching': 765,
#  'verges': 766,
#  'verger': 767,
#  'kohl': 768,
#  'conditioned': 769,
#  'eighteen': 770,
#  'waddell': 771,
#  'hyperdrive': 772,
#  'conditioner': 773,
#  'verged': 775,
#  'insatiable': 23909,
#  'hone': 777,
#  'hong': 4715,
#  'dazza': 4720,
#  'inventively': 780,
#  'rapyuta': 781,
#  'jolting': 782,
#  'remand': 4743,
#  'mummified': 784,
#  'honk': 785,
#  'spews': 786,
#  'split': 787,
#  'visitations': 789,
#  'codename': 790,
#  'principals': 791,
#  'cavanaugh': 792,
#  'junge': 793,
#  'zeon': 795,
#  'supped': 796,
#  'watcing': 797,
#  'boiled': 798,
#  'effortlessly': 799,
#  'inadvertently': 4825,
#  'frenchmen': 801,
#  'vivien': 802,
#  'qualifications': 803,
#  'workforce': 804,
#  'dtr': 62298,
#  'consents': 805,
#  'boiler': 806,
#  'schlessinger': 807,
#  'supper': 808,
#  'torpedoed': 809,
#  'featherweight': 810,
#  'blister': 72035,
#  'pacey': 41682,
#  'cinefest': 812,
#  'furlough': 813,
#  'attacker': 42978,
#  'buchfellner': 815,
#  'pardesi': 51781,
#  'kamina': 816,
#  'mainsequence': 817,
#  'mentors': 818,
#  'academic': 819,
#  'stillness': 820,
#  'academia': 821,
#  'goofing': 822,
#  'nibby': 823,
#  'exhooker': 824,
#  'cineastes': 825,
#  'odile': 54966,
#  'dirtying': 70146,
#  'corporate': 826,
#  'massaging': 827,
#  'plaque': 828,
#  'zestful': 70910,
#  'outlived': 830,
#  'gigolo': 5012,
#  'absurdities': 832,
#  'appropriately': 833,
#  'unabsorbing': 5033,
#  'antagonists': 38455,
#  'portrayer': 835,
#  'linehan': 836,
#  'roadrunner': 36107,
#  'vallee': 71468,
#  'snickered': 839,
#  'visability': 840,
#  'pakage': 841,
#  'airbag': 842,
#  'manikins': 52910,
#  'portrayed': 843,
#  'gainsbourg': 844,
#  'hah': 845,
#  'hai': 846,
#  'haj': 5122,
#  'hak': 848,
#  'hal': 849,
#  'ham': 850,
#  'duffer': 851,
#  'coatesville': 852,
#  'haa': 853,
#  'espouses': 5147,
#  'had': 855,
#  'advancement': 856,
#  'hag': 857,
#  'hay': 858,
#  'mcnamara': 859,
#  'beloved': 860,
#  'duffel': 861,
#  'haq': 862,
#  'har': 863,
#  'has': 864,
#  'hat': 865,
#  'preciously': 866,
#  'hav': 867,
#  'haw': 868,
#  'buffoonish': 68682,
#  'guilts': 51200,
#  'biehn': 53836,
#  'cocked': 54514,
#  'figtings': 5237,
#  'confidentially': 870,
#  'elders': 871,
#  'survival': 872,
#  'siesta': 61149,
#  'underpanted': 874,
#  'pninson': 875,
#  'unequivocally': 876,
#  'palazzo': 23922,
#  'otherworldly': 878,
#  'indicative': 879,
#  'connely': 61150,
#  'hexploitation': 882,
#  'shadow': 883,
#  'flotsam': 36113,
#  'sheeta': 65172,
#  'sleuthing': 886,
#  'masonic': 887,
#  'gadi': 888,
#  'delectably': 889,
#  'killling': 60642,
#  'amfortas': 890,
#  'gadg': 891,
#  'alice': 892,
#  'pubert': 893,
#  'boasts': 67639,
#  'festivities': 894,
#  'lalouche': 895,
#  'debell': 896,
#  'airball': 897,
#  'shipyard': 46845,
#  'misdemeanors': 898,
#  'warping': 899,
#  'attorney': 900,
#  'flub': 48528,
#  'sours': 51116,
#  'trudie': 902,
#  'crowd': 903,
#  'crowe': 904,
#  'czech': 905,
#  'mosques': 906,
#  'crown': 907,
#  'postmaster': 61157,
#  'culpas': 909,
#  'policewoman': 69738,
#  'captive': 910,
#  'surrell': 911,
#  'flowless': 912,
#  'sheirk': 913,
#  'billboard': 914,
#  'stealthily': 915,
#  'ooverall': 916,
#  'unadaptable': 917,
#  'perchance': 918,
#  'bottom': 919,
#  'pileggi': 920,
#  'surroundsound': 50488,
#  'inhuman': 922,
#  'plucked': 923,
#  'repleat': 924,
#  'caribbean': 71382,
#  'tasuieva': 926,
#  'treadmill': 927,
#  'ursla': 48532,
#  'monogamy': 929,
#  'completly': 930,
#  'disliking': 66164,
#  'howell': 931,
#  'wackiness': 61162,
#  'rooker': 932,
#  'fish': 47951,
#  'herzogian': 934,
#  'raddick': 935,
#  'barcode': 936,
#  'eduard': 937,
#  'soppiness': 69655,
#  'unmarysuish': 938,
#  'binder': 939,
#  'brigades': 940,
#  'starring': 942,
#  'mediocrity': 48535,
#  'filaments': 944,
#  'disdains': 945,
#  'willcock': 946,
#  'stoker': 947,
#  'collete': 948,
#  'tai': 73068,
#  'spaceships': 949,
#  'elicots': 950,
#  'hexing': 951,
#  'filmcritic': 952,
#  'bensonhurst': 953,
#  'wt': 73108,
#  'anomalous': 955,
#  'wheatena': 48538,
#  'savala': 958,
#  'lurching': 68406,
#  'oneness': 959,
#  'stoked': 960,
#  'shirdan': 961,
#  'cinematographical': 963,
#  'expertly': 61168,
#  'lemmings': 965,
#  'duccio': 966,
#  'quaaludes': 967,
#  'brownesque': 968,
#  'maxwell': 970,
#  'marshall': 971,
#  'honeymoon': 972,
#  'mba': 974,
#  'mbb': 975,
#  'lieber': 976,
#  'administer': 977,
#  'beings': 978,
#  'jaekel': 979,
#  'unrecognisable': 981,
#  'shoots': 982,
#  'surround': 51309,
#  'despised': 983,
#  'okabasho': 984,
#  'tamo': 5994,
#  'finially': 27688,
#  'altitude': 986,
#  'daves': 57340,
#  'tame': 988,
#  'grasping': 990,
#  'despises': 991,
#  'greatness': 993,
#  'rapes': 994,
#  'raper': 995,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1
    
update_input_layer(reviews[0])

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == "POSITIVE":
        return 1
    else:
        return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):2.757 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:2.02% Speed(reviews/sec):2.456 #Correct:243 #Trained:486 Training Accuracy:50.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-ad0ddebea879> in <module>()
# ----> 1 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-51-132cc2d9bc28> in train(self, training_reviews, training_labels)
#     131
#     132             # Input Layer
# --> 133             self.update_input_layer(review)
#     134
#     135             # Hidden layer
#
# <ipython-input-51-132cc2d9bc28> in update_input_layer(self, review)
#      93             #       with raise an exception in Python. This allows us to ignore unknown
#      94             #       words encountered in new reviews.
# ---> 95             if(word in self.word2index.keys()):
#      96                 self.layer_0[0][self.word2index[word]] += 1
#      97
#
# KeyboardInterrupt:

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        
        for word in review.split(" "):
            # NOTE: This if-check was not in the version of this method created in Project 2,
            #       and it appears in Andrew's Project 3 solution without explanation. 
            #       It simply ensures the word is actually a key in word2index before
            #       accessing it, which is important because accessing an invalid key
            #       with raise an exception in Python. This allows us to ignore unknown
            #       words encountered in new reviews.
            if(word in self.word2index.keys()):
                ## New for Project 4: changed to set to 1 instead of add 1
                self.layer_0[0][self.word2index[word]] = 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:0.83% Speed(reviews/sec):2.384 #Correct:108 #Trained:201 Training Accuracy:53.7%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-730eec38f1d1> in <module>()
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-56-b251f600d492> in train(self, training_reviews, training_labels)
#     133
#     134             # Input Layer
# --> 135             self.update_input_layer(review)
#     136
#     137             # Hidden layer
#
# <ipython-input-56-b251f600d492> in update_input_layer(self, review)
#      94             #       with raise an exception in Python. This allows us to ignore unknown
#      95             #       words encountered in new reviews.
# ---> 96             if(word in self.word2index.keys()):
#      97                 ## New for Project 4: changed to set to 1 instead of add 1
#      98                 self.layer_0[0][self.word2index[word]] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        ## New for Project 5: Removed self.layer_0; added self.layer_1
        # The input layer, a two-dimensional matrix with shape 1 x hidden_nodes
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    ## New for Project 5: Removed update_input_layer function
    
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    ## New for Project 5: changed name of first parameter form 'training_reviews' 
    #                     to 'training_reviews_raw'
    def train(self, training_reviews_raw, training_labels):

        ## New for Project 5: pre-process training reviews so we can deal 
        #                     directly with the indices of non-zero inputs
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            ## New for Project 5: Removed call to 'update_input_layer' function
            #                     because 'layer_0' is no longer used

            # Hidden layer
            ## New for Project 5: Add in only the weights for non-zero items
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

            # Output layer
            ## New for Project 5: changed to use 'self.layer_1' instead of 'local layer_1'
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            ## New for Project 5: changed to use 'self.layer_1' instead of local 'layer_1'
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            ## New for Project 5: Only update the weights that were used in the forward pass
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        ## New for Project 5: Removed call to update_input_layer function
        #                     because layer_0 is no longer used

        # Hidden layer
        ## New for Project 5: Identify the indices used in the review and then add
        #                     just those weights to layer_1 
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        ## New for Project 5: changed to use self.layer_1 instead of local layer_1
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-730eec38f1d1> in <module>()
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-58-783d7d12256b> in train(self, training_reviews_raw, training_labels)
#     106             indices = set()
#     107             for word in review.split(" "):
# --> 108                 if(word in self.word2index.keys()):
#     109                     indices.add(self.word2index[word])
#     110             training_reviews.append(list(indices))
#
# KeyboardInterrupt:

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 0.990909090909091),
#  ('antwone', 0.9887640449438202),
#  ('din', 0.9879518072289156),
#  ('gunga', 0.9850746268656716),
#  ('goldsworthy', 0.9848484848484849),
#  ('gypo', 0.9836065573770492),
#  ('yokai', 0.9836065573770492),
#  ('flavia', 0.9807692307692307),
#  ('visconti', 0.9807692307692307),
#  ('blandings', 0.9795918367346939),
#  ('kells', 0.9795918367346939),
#  ('brashear', 0.9791666666666666),
#  ('gino', 0.9787234042553191),
#  ('deathtrap', 0.9782608695652174),
#  ('panahi', 0.9761904761904762),
#  ('harilal', 0.9761904761904762),
#  ('paulie', 0.9752066115702479),
#  ('ossessione', 0.975),
#  ('tsui', 0.9743589743589743),
#  ('caruso', 0.9743589743589743),
#  ('ahmad', 0.9736842105263158),
#  ('sabu', 0.9736842105263158),
#  ('dominick', 0.972972972972973),
#  ('khouri', 0.972972972972973),
#  ('mj', 0.9722222222222222),
#  ('aweigh', 0.9722222222222222),
#  ('kriemhild', 0.9714285714285714),
#  ('mcintire', 0.9714285714285714),
#  ('newcombe', 0.9705882352941176),
#  ('daisies', 0.9705882352941176),
#  ('blackie', 0.9705882352941176),
#  ('trelkovsky', 0.9696969696969697),
#  ('kei', 0.9696969696969697),
#  ('hilliard', 0.96875),
#  ('jaffar', 0.96875),
#  ('offside', 0.967741935483871),
#  ('sheeta', 0.967741935483871),
#  ('krell', 0.967741935483871),
#  ('bathsheba', 0.967741935483871),
#  ('pazu', 0.967741935483871),
#  ('venoms', 0.9666666666666667),
#  ('fineman', 0.9666666666666667),
#  ('ranma', 0.9655172413793104),
#  ('paine', 0.9655172413793104),
#  ('ronny', 0.9655172413793104),
#  ('pimlico', 0.9655172413793104),
#  ('abhay', 0.9642857142857143),
#  ('kipling', 0.9629629629629629),
#  ('pym', 0.9629629629629629),
#  ('audiard', 0.9615384615384616),
#  ('milverton', 0.9615384615384616),
#  ('gabe', 0.9615384615384616),
#  ('scalise', 0.9615384615384616),
#  ('kelso', 0.9615384615384616),
#  ('mukhsin', 0.96),
#  ('moonwalker', 0.96),
#  ('xica', 0.96),
#  ('grisby', 0.96),
#  ('heaton', 0.9583333333333334),
#  ('jannings', 0.9583333333333334),
#  ('togar', 0.9583333333333334),
#  ('chikatilo', 0.9583333333333334),
#  ('leonora', 0.9565217391304348),
#  ('desdemona', 0.9565217391304348),
#  ('pidgeon', 0.9565217391304348),
#  ('matador', 0.9565217391304348),
#  ('matuschek', 0.9565217391304348),
#  ('soha', 0.9565217391304348),
#  ('fanfan', 0.9565217391304348),
#  ('miklos', 0.9565217391304348),
#  ('maradona', 0.9545454545454546),
#  ('joss', 0.9545454545454546),
#  ('microfilm', 0.9545454545454546),
#  ('bjm', 0.9545454545454546),
#  ('gauri', 0.9545454545454546),
#  ('firemen', 0.9545454545454546),
#  ('reda', 0.9545454545454546),
#  ('siegfried', 0.9523809523809523),
#  ('quibble', 0.9523809523809523),
#  ('mcintyre', 0.9523809523809523),
#  ('emory', 0.9523809523809523),
#  ('coonskin', 0.9523809523809523),
#  ('coe', 0.9523809523809523),
#  ('carrre', 0.9523809523809523),
#  ('prote', 0.9523809523809523),
#  ('flippen', 0.95),
#  ('hillyer', 0.95),
#  ('burakov', 0.95),
#  ('malfique', 0.95),
#  ('versatility', 0.95),
#  ('magnus', 0.95),
#  ('petiot', 0.95),
#  ('pakeezah', 0.95),
#  ('rvd', 0.95),
#  ('railly', 0.95),
#  ('pinjar', 0.95),
#  ('ackland', 0.95),
#  ('ferdie', 0.95),
#  ('schlesinger', 0.95),
#  ('knockout', 0.95),
#  ('baloo', 0.95),
#  ('digicorp', 0.95),
#  ('gundam', 0.9484536082474226),
#  ('burgade', 0.9473684210526315),
#  ('volckman', 0.9473684210526315),
#  ('falco', 0.9473684210526315),
#  ('hobson', 0.9473684210526315),
#  ('iek', 0.9473684210526315),
#  ('pollak', 0.9473684210526315),
#  ('lando', 0.9473684210526315),
#  ('geer', 0.9473684210526315),
#  ('pappas', 0.9473684210526315),
#  ('iphigenia', 0.9473684210526315),
#  ('hoechlin', 0.9473684210526315),
#  ('guerrero', 0.9473684210526315),
#  ('iturbi', 0.9464285714285714),
#  ('jeon', 0.9444444444444444),
#  ('toughness', 0.9444444444444444),
#  ('nagra', 0.9444444444444444),
#  ('naudet', 0.9444444444444444),
#  ('peralta', 0.9444444444444444),
#  ('hewlett', 0.9444444444444444),
#  ('beckett', 0.9444444444444444),
#  ('nighy', 0.9444444444444444),
#  ('cdric', 0.9444444444444444),
#  ('jacknife', 0.9444444444444444),
#  ('orked', 0.9444444444444444),
#  ('kralik', 0.9444444444444444),
#  ('natalia', 0.9411764705882353),
#  ('yvaine', 0.9411764705882353),
#  ('rotj', 0.9411764705882353),
#  ('bombshells', 0.9411764705882353),
#  ('hulce', 0.9411764705882353),
#  ('delpy', 0.9411764705882353),
#  ('antz', 0.9411764705882353),
#  ('feinstone', 0.9411764705882353),
#  ('endor', 0.9411764705882353),
#  ('firefighter', 0.9411764705882353),
#  ('coulouris', 0.9411764705882353),
#  ('macready', 0.9411764705882353),
#  ('bedknobs', 0.9411764705882353),
#  ('santos', 0.9411764705882353),
#  ('gaiman', 0.9411764705882353),
#  ('duffell', 0.9411764705882353),
#  ('giovanna', 0.9411764705882353),
#  ('janos', 0.9411764705882353),
#  ('mcanally', 0.9375),
#  ('lanisha', 0.9375),
#  ('baton', 0.9375),
#  ('cognac', 0.9375),
#  ('johnnie', 0.9375),
#  ('egon', 0.9375),
#  ('gunbuster', 0.9375),
#  ('ballantine', 0.9375),
#  ('calamai', 0.9375),
#  ('luzhin', 0.9375),
#  ('doktor', 0.9375),
#  ('soutendijk', 0.9375),
#  ('hilda', 0.9375),
#  ('kiley', 0.9375),
#  ('shintaro', 0.9375),
#  ('lian', 0.9375),
#  ('karas', 0.9375),
#  ('valette', 0.9375),
#  ('grasshoppers', 0.9375),
#  ('parador', 0.9375),
#  ('goines', 0.9375),
#  ('cheh', 0.9375),
#  ('schildkraut', 0.9375),
#  ('oro', 0.9375),
#  ('uld', 0.9375),
#  ('silberling', 0.9375),
#  ('burman', 0.9375),
#  ('rotoscoped', 0.9375),
#  ('philo', 0.9347826086956522),
#  ('tulip', 0.9333333333333333),
#  ('melancholic', 0.9333333333333333),
#  ('ingram', 0.9333333333333333),
#  ('gardenia', 0.9333333333333333),
#  ('pilgrimage', 0.9333333333333333),
#  ('emy', 0.9333333333333333),
#  ('laine', 0.9333333333333333),
#  ('embezzler', 0.9333333333333333),
#  ('rien', 0.9333333333333333),
#  ('cb', 0.9333333333333333),
#  ('kabei', 0.9333333333333333),
#  ('scrat', 0.9333333333333333),
#  ('duprez', 0.9333333333333333),
#  ('gialli', 0.9333333333333333),
#  ('treaty', 0.9333333333333333),
#  ('beek', 0.9333333333333333),
#  ('hickam', 0.9333333333333333),
#  ('lindy', 0.9333333333333333),
#  ('intricately', 0.9333333333333333),
#  ('atoz', 0.9333333333333333),
#  ('bathhouse', 0.9333333333333333),
#  ('cartwrights', 0.9333333333333333),
#  ('megs', 0.9333333333333333),
#  ('danelia', 0.9333333333333333),
#  ('ishwar', 0.9333333333333333),
#  ('kulkarni', 0.9333333333333333),
#  ('fetisov', 0.9333333333333333),
#  ('cynics', 0.9285714285714286),
#  ('choi', 0.9285714285714286),
#  ('goring', 0.9285714285714286),
#  ('girotti', 0.9285714285714286),
#  ('erendira', 0.9285714285714286),
#  ('eglantine', 0.9285714285714286),
#  ('felix', 0.9285714285714286),
#  ('brownstone', 0.9285714285714286),
#  ('gabriella', 0.9285714285714286),
#  ('adjani', 0.9285714285714286),
#  ('holloway', 0.9285714285714286),
#  ('dola', 0.9285714285714286),
#  ('luchino', 0.9285714285714286),
#  ('oakie', 0.9285714285714286),
#  ('guadalcanal', 0.9285714285714286),
#  ('bouvier', 0.9285714285714286),
#  ('tissues', 0.9285714285714286),
#  ('chavo', 0.9285714285714286),
#  ('nibelungen', 0.9285714285714286),
#  ('sugiyama', 0.9285714285714286),
#  ('mcdoakes', 0.9285714285714286),
#  ('broadbent', 0.9285714285714286),
#  ('clutter', 0.9285714285714286),
#  ('sputnik', 0.9285714285714286),
#  ('autograph', 0.9285714285714286),
#  ('unsung', 0.9285714285714286),
#  ('bahrain', 0.9285714285714286),
#  ('riget', 0.9285714285714286),
#  ('freebird', 0.9285714285714286),
#  ('odysseus', 0.9285714285714286),
#  ('yelnats', 0.9285714285714286),
#  ('boop', 0.9285714285714286),
#  ('anchors', 0.926829268292683),
#  ('capote', 0.9242424242424242),
#  ('natures', 0.9230769230769231),
#  ('hayao', 0.9230769230769231),
#  ('cacoyannis', 0.9230769230769231),
#  ('herge', 0.9230769230769231),
#  ('bouzaglo', 0.9230769230769231),
#  ('anselmo', 0.9230769230769231),
#  ('luger', 0.9230769230769231),
#  ('holodeck', 0.9230769230769231),
#  ('lafitte', 0.9230769230769231),
#  ('barrister', 0.9230769230769231),
#  ('mcphillip', 0.9230769230769231),
#  ('yeon', 0.9230769230769231),
#  ('trenholm', 0.9230769230769231),
#  ('lassalle', 0.9230769230769231),
#  ('mcadam', 0.9230769230769231),
#  ('euripides', 0.9230769230769231),
#  ('hecht', 0.9230769230769231),
#  ('rideau', 0.9230769230769231),
#  ('strindberg', 0.9230769230769231),
#  ('clutters', 0.9230769230769231),
#  ('killian', 0.9230769230769231),
#  ('presque', 0.9230769230769231),
#  ('santiago', 0.9230769230769231),
#  ('poonam', 0.9230769230769231),
#  ('attila', 0.9230769230769231),
#  ('parminder', 0.9230769230769231),
#  ('bressart', 0.9230769230769231),
#  ('bischoff', 0.9230769230769231),
#  ('vierde', 0.9230769230769231),
#  ('balduin', 0.9230769230769231),
#  ('talos', 0.9230769230769231),
#  ('hanlon', 0.9230769230769231),
#  ('gallico', 0.9230769230769231),
#  ('excellently', 0.921875),
#  ('korda', 0.9210526315789473),
#  ('fido', 0.9204545454545454),
#  ('callahan', 0.918918918918919),
#  ('deanna', 0.9180327868852459),
#  ('hayworth', 0.9180327868852459),
#  ('rawhide', 0.9166666666666666),
#  ('nord', 0.9166666666666666),
#  ('vadar', 0.9166666666666666),
#  ('tykwer', 0.9166666666666666),
#  ('unsurpassed', 0.9166666666666666),
#  ('gracia', 0.9166666666666666),
#  ('taoist', 0.9166666666666666),
#  ('hanka', 0.9166666666666666),
#  ('eminent', 0.9166666666666666),
#  ('bartel', 0.9166666666666666),
#  ('fellowes', 0.9166666666666666),
#  ('sweetin', 0.9166666666666666),
#  ('starewicz', 0.9166666666666666),
#  ('nandini', 0.9166666666666666),
#  ('soapdish', 0.9166666666666666),
#  ('leaud', 0.9166666666666666),
#  ('gorris', 0.9166666666666666),
#  ('spacecamp', 0.9166666666666666),
#  ('regent', 0.9166666666666666),
#  ('prologues', 0.9166666666666666),
#  ('fanshawe', 0.9166666666666666),
#  ('eisenhower', 0.9166666666666666),
#  ('rf', 0.9166666666666666),
#  ('filone', 0.9166666666666666),
#  ('pei', 0.9166666666666666),
#  ('wilhelm', 0.9166666666666666),
#  ('showings', 0.9166666666666666),
#  ('bruhl', 0.9166666666666666),
#  ('lok', 0.9166666666666666),
#  ('atul', 0.9166666666666666),
#  ('aiello', 0.9166666666666666),
#  ('seine', 0.9166666666666666),
#  ('zp', 0.9166666666666666),
#  ('stitzer', 0.9166666666666666),
#  ('hallen', 0.9166666666666666),
#  ('faust', 0.9166666666666666),
#  ('dorfman', 0.9166666666666666),
#  ('huns', 0.9166666666666666),
#  ('gundams', 0.9166666666666666),
#  ('yasmin', 0.9166666666666666),
#  ('muska', 0.9166666666666666),
#  ('dragoon', 0.9166666666666666),
#  ('bolan', 0.9166666666666666),
#  ('nyqvist', 0.9166666666666666),
#  ('thursby', 0.9166666666666666),
#  ('bazza', 0.9166666666666666),
#  ('arrondissement', 0.9166666666666666),
#  ('shep', 0.9166666666666666),
#  ('capano', 0.9166666666666666),
#  ('tetsur', 0.9166666666666666),
#  ('dorsey', 0.9166666666666666),
#  ('cannavale', 0.9166666666666666),
#  ('hoss', 0.9166666666666666),
#  ('cookbook', 0.9166666666666666),
#  ('sjoman', 0.9166666666666666),
#  ('viennese', 0.9166666666666666),
#  ('antonietta', 0.9166666666666666),
#  ('faultless', 0.9166666666666666),
#  ('vance', 0.9156626506024096),
#  ('kolchak', 0.9146341463414634),
#  ('sammo', 0.9122807017543859),
#  ('bake', 0.9117647058823529),
#  ('laputa', 0.9107142857142857),
#  ('kidd', 0.9090909090909091),
#  ('portobello', 0.9090909090909091),
#  ('restoring', 0.9090909090909091),
#  ('unparalleled', 0.9090909090909091),
#  ('topher', 0.9090909090909091),
#  ('gwizdo', 0.9090909090909091),
#  ('ankush', 0.9090909090909091),
#  ('lifshitz', 0.9090909090909091),
#  ('rollicking', 0.9090909090909091),
#  ('ginty', 0.9090909090909091),
#  ('separating', 0.9090909090909091),
#  ('ernesto', 0.9090909090909091),
#  ('bowser', 0.9090909090909091),
#  ('philipps', 0.9090909090909091),
#  ('athens', 0.9090909090909091),
#  ('levitt', 0.9090909090909091),
#  ('gilberte', 0.9090909090909091),
#  ('pquerette', 0.9090909090909091),
#  ('rhapsody', 0.9090909090909091),
#  ('calvet', 0.9090909090909091),
#  ('jermaine', 0.9090909090909091),
#  ('fps', 0.9090909090909091),
#  ('sikes', 0.9090909090909091),
#  ('gervais', 0.9090909090909091),
#  ('broinowski', 0.9090909090909091),
#  ('hisaishi', 0.9090909090909091),
#  ('eustache', 0.9090909090909091),
#  ('ghibli', 0.9090909090909091),
#  ('randell', 0.9090909090909091),
#  ('katey', 0.9090909090909091),
#  ('floraine', 0.9090909090909091),
#  ('arzenta', 0.9090909090909091),
#  ('thornway', 0.9090909090909091),
#  ('zechs', 0.9090909090909091),
#  ('ref', 0.9090909090909091),
#  ('waterloo', 0.9090909090909091),
#  ('rudyard', 0.9090909090909091),
#  ('swashbucklers', 0.9090909090909091),
#  ('poldi', 0.9090909090909091),
#  ('manfred', 0.9090909090909091),
#  ('aviv', 0.9090909090909091),
#  ('miou', 0.9090909090909091),
#  ('waxworks', 0.9090909090909091),
#  ('strickland', 0.9090909090909091),
#  ('virile', 0.9090909090909091),
#  ('chamberlains', 0.9090909090909091),
#  ('ori', 0.9090909090909091),
#  ('rozsa', 0.9090909090909091),
#  ('trnka', 0.9090909090909091),
#  ('overpopulation', 0.9090909090909091),
#  ('yam', 0.9090909090909091),
#  ('hickock', 0.9090909090909091),
#  ('prag', 0.9090909090909091),
#  ('wuhl', 0.9090909090909091),
#  ('pneumonic', 0.9090909090909091),
#  ('tollinger', 0.9090909090909091),
#  ('strombel', 0.9090909090909091),
#  ('ashraf', 0.9090909090909091),
#  ('margo', 0.9090909090909091),
#  ('hardworking', 0.9090909090909091),
#  ('quebec', 0.9090909090909091),
#  ('shetty', 0.9090909090909091),
#  ('pasdar', 0.9090909090909091),
#  ('hickcock', 0.9090909090909091),
#  ('beale', 0.9090909090909091),
#  ('mariner', 0.9090909090909091),
#  ('parkins', 0.9090909090909091),
#  ('milyang', 0.9090909090909091),
#  ('maetel', 0.9090909090909091),
#  ('hemo', 0.9090909090909091),
#  ('tam', 0.9090909090909091),
#  ('apatow', 0.9090909090909091),
#  ('spanky', 0.9090909090909091),
#  ('sox', 0.9066666666666666),
#  ('partition', 0.90625),
#  ('beery', 0.90625),
#  ('dench', 0.90625),
#  ('conroy', 0.90625),
#  ('alvin', 0.9054054054054054),
#  ('biko', 0.9042553191489362),
#  ('adele', 0.9038461538461539),
#  ('gackt', 0.9038461538461539),
#  ('myrtle', 0.9038461538461539),
#  ('pang', 0.9032258064516129),
#  ('polanski', 0.9017857142857143),
#  ('mathieu', 0.9014084507042254),
#  ('dickey', 0.9),
#  ('verger', 0.9),
#  ('hickory', 0.9),
#  ('hazlehurst', 0.9),
#  ('omnibus', 0.9),
#  ('tronje', 0.9),
#  ('qualifying', 0.9),
#  ('hermione', 0.9),
#  ('gespenster', 0.9),
#  ('timone', 0.9),
#  ('pedicab', 0.9),
#  ('sumpter', 0.9),
#  ('mes', 0.9),
#  ('gulpilil', 0.9),
#  ('managers', 0.9),
#  ('stig', 0.9),
#  ('faceted', 0.9),
#  ('nwh', 0.9),
#  ('frulein', 0.9),
#  ('maxx', 0.9),
#  ('cruiserweight', 0.9),
#  ('ferland', 0.9),
#  ('guignol', 0.9),
#  ('bizet', 0.9),
#  ('tatsuhito', 0.9),
#  ('faubourg', 0.9),
#  ('katsu', 0.9),
#  ('brimmer', 0.9),
#  ('torrens', 0.9),
#  ('grayce', 0.9),
#  ('jeffs', 0.9),
#  ('tuileries', 0.9),
#  ('vue', 0.9),
#  ('doubtlessly', 0.9),
#  ('proust', 0.9),
#  ('bernsen', 0.9),
#  ('fricker', 0.9),
#  ('lata', 0.9),
#  ('scarwid', 0.9),
#  ('romantics', 0.9),
#  ('madhubala', 0.9),
#  ('lago', 0.9),
#  ('dev', 0.9),
#  ('lawton', 0.9),
#  ('informant', 0.9),
#  ('salazar', 0.9),
#  ('loners', 0.9),
#  ('montmartre', 0.9),
#  ('hom', 0.9),
#  ('peretti', 0.9),
#  ('louella', 0.9),
#  ('emil', 0.9),
#  ('xu', 0.9),
#  ('cassio', 0.9),
#  ('giuseppe', 0.9),
#  ('szifron', 0.9),
#  ('dumbrille', 0.9),
#  ('livesey', 0.9),
#  ('banjos', 0.9),
#  ('kleinman', 0.9),
#  ('lebrun', 0.9),
#  ('imperioli', 0.9),
#  ('transports', 0.9),
#  ('gannon', 0.9),
#  ('peepers', 0.9),
#  ('vernacular', 0.9),
#  ('smita', 0.9),
#  ('macchesney', 0.9),
#  ('herr', 0.9),
#  ('feroz', 0.9),
#  ('machaty', 0.9),
#  ('bte', 0.9),
#  ('futures', 0.9),
#  ('sachar', 0.9),
#  ('marchand', 0.9),
#  ('forged', 0.9),
#  ('luque', 0.9),
#  ('coulardeau', 0.9),
#  ('matthau', 0.8975903614457831),
#  ('gilliam', 0.8970588235294118),
#  ('saura', 0.896551724137931),
#  ('binder', 0.8888888888888888),
#  ('thrive', 0.8888888888888888),
#  ('salva', 0.8888888888888888),
#  ('bakersfield', 0.8888888888888888),
#  ('blackadder', 0.8888888888888888),
#  ('kaakha', 0.8888888888888888),
#  ('littlefield', 0.8888888888888888),
#  ('windmill', 0.8888888888888888),
#  ('pleasence', 0.8888888888888888),
#  ('zorak', 0.8888888888888888),
#  ('basra', 0.8888888888888888),
#  ('alekos', 0.8888888888888888),
#  ('saks', 0.8888888888888888),
#  ('nyree', 0.8888888888888888),
#  ('interweaving', 0.8888888888888888),
#  ('intimidated', 0.8888888888888888),
#  ('zhu', 0.8888888888888888),
#  ('amplified', 0.8888888888888888),
#  ('sandhya', 0.8888888888888888),
#  ('shinae', 0.8888888888888888),
#  ('harriet', 0.8888888888888888),
#  ('lachaise', 0.8888888888888888),
#  ('bragana', 0.8888888888888888),
#  ('versailles', 0.8888888888888888),
#  ('inaccessible', 0.8888888888888888),
#  ('yuzna', 0.8888888888888888),
#  ('jodelle', 0.8888888888888888),
#  ('cristy', 0.8888888888888888),
#  ('valientes', 0.8888888888888888),
#  ('chavez', 0.8888888888888888),
#  ('cabell', 0.8888888888888888),
#  ('hohl', 0.8888888888888888),
#  ('revere', 0.8888888888888888),
#  ('stphane', 0.8888888888888888),
#  ('kemble', 0.8888888888888888),
#  ('kangwon', 0.8888888888888888),
#  ('yamamoto', 0.8888888888888888),
#  ('hennessy', 0.8888888888888888),
#  ('bedchamber', 0.8888888888888888),
#  ('marais', 0.8888888888888888),
#  ('lodoss', 0.8888888888888888),
#  ('technicolour', 0.8888888888888888),
#  ('carax', 0.8888888888888888),
#  ('forge', 0.8888888888888888),
#  ('ashura', 0.8888888888888888),
#  ('hiralal', 0.8888888888888888),
#  ('euthanasia', 0.8888888888888888),
#  ('gades', 0.8888888888888888),
#  ('grot', 0.8888888888888888),
#  ('captivates', 0.8888888888888888),
#  ('awsome', 0.8888888888888888),
#  ('salles', 0.8888888888888888),
#  ('jafri', 0.8888888888888888),
#  ('meyerling', 0.8888888888888888),
#  ('fastway', 0.8888888888888888),
#  ('unpretentious', 0.8888888888888888),
#  ('touchingly', 0.8888888888888888),
#  ('rambeau', 0.8888888888888888),
#  ('lupino', 0.8888888888888888),
#  ('brommel', 0.8888888888888888),
#  ('boesman', 0.8888888888888888),
#  ('peaches', 0.8888888888888888),
#  ('mnm', 0.8888888888888888),
#  ('mathis', 0.8888888888888888),
#  ('disarming', 0.8888888888888888),
#  ('queenie', 0.8888888888888888),
#  ('trampa', 0.8888888888888888),
#  ('ezra', 0.8888888888888888),
#  ('nekron', 0.8888888888888888),
#  ('yin', 0.8888888888888888),
#  ('bromwell', 0.8888888888888888),
#  ('tiempo', 0.8888888888888888),
#  ('kopins', 0.8888888888888888),
#  ('locataire', 0.8888888888888888),
#  ('stettner', 0.8888888888888888),
#  ('malleson', 0.8888888888888888),
#  ('arias', 0.8888888888888888),
#  ('tingler', 0.8888888888888888),
#  ('goodrich', 0.8888888888888888),
#  ('benito', 0.8888888888888888),
#  ('patil', 0.8888888888888888),
#  ('ryker', 0.8888888888888888),
#  ('herg', 0.8888888888888888),
#  ('boundless', 0.8888888888888888),
#  ('shinjuku', 0.8888888888888888),
#  ('gainax', 0.8888888888888888),
#  ('genma', 0.8888888888888888),
#  ('johanson', 0.8888888888888888),
#  ('tieh', 0.8888888888888888),
#  ('micheaux', 0.8888888888888888),
#  ('eon', 0.8888888888888888),
#  ('sagal', 0.8888888888888888),
#  ('olan', 0.8888888888888888),
#  ('etzel', 0.8888888888888888),
#  ('sharpshooter', 0.8888888888888888),
#  ('perdition', 0.8888888888888888),
#  ('alta', 0.8888888888888888),
#  ('improvising', 0.8888888888888888),
#  ('unafraid', 0.8888888888888888),
#  ('pernell', 0.8888888888888888),
#  ('catiii', 0.8888888888888888),
#  ('rostov', 0.8888888888888888),
#  ('valseuses', 0.8888888888888888),
#  ('cinematographers', 0.8888888888888888),
#  ('nihalani', 0.8888888888888888),
#  ('thuggee', 0.8888888888888888),
#  ('munshi', 0.8888888888888888),
#  ('ciannelli', 0.8888888888888888),
#  ('dimaggio', 0.8888888888888888),
#  ('taj', 0.8888888888888888),
#  ('apophis', 0.8888888888888888),
#  ('ratso', 0.8875),
#  ('ultimatum', 0.8852459016393442),
#  ('jonestown', 0.8846153846153846),
#  ('godmother', 0.8846153846153846),
#  ('mahatma', 0.8846153846153846),
#  ('judi', 0.8846153846153846),
#  ('abbey', 0.8846153846153846),
#  ('mcnally', 0.8846153846153846),
#  ('zu', 0.8837209302325582),
#  ('sammi', 0.8837209302325582),
#  ('abu', 0.8837209302325582),
#  ('warhols', 0.8837209302325582),
#  ('victoria', 0.8830645161290323),
#  ('rosenstrasse', 0.8809523809523809),
#  ('noriko', 0.88),
#  ('pike', 0.88),
#  ('woronov', 0.88),
#  ('waterman', 0.88),
#  ('stockwell', 0.88),
#  ('radiant', 0.88),
#  ('mildred', 0.8780487804878049),
#  ('delightfully', 0.8771929824561403),
#  ('corbett', 0.8767123287671232),
#  ('mclaglen', 0.8764044943820225),
#  ('chambara', 0.875),
#  ('zeon', 0.875),
#  ('symmetry', 0.875),
#  ('borough', 0.875),
#  ('busfield', 0.875),
#  ('johnston', 0.875),
#  ('guarding', 0.875),
#  ('mcdiarmid', 0.875),
#  ('warfield', 0.875),
#  ('jouvet', 0.875),
#  ('conceptions', 0.875),
#  ('creasy', 0.875),
#  ('dicken', 0.875),
#  ('prosper', 0.875),
#  ('loulou', 0.875),
#  ('heyerdahl', 0.875),
#  ('aurora', 0.875),
#  ('personifies', 0.875),
#  ('moroder', 0.875),
#  ('overjoyed', 0.875),
#  ('kaley', 0.875),
#  ('costly', 0.875),
#  ('tessari', 0.875),
#  ('kel', 0.875),
#  ('korsmo', 0.875),
#  ('superstardom', 0.875),
#  ('eikenberry', 0.875),
#  ('pepi', 0.875),
#  ('ligabue', 0.875),
#  ('rapids', 0.875),
#  ('mattox', 0.875),
#  ('melfi', 0.875),
#  ('geoff', 0.875),
#  ('wardh', 0.875),
#  ('mimics', 0.875),
#  ('brisson', 0.875),
#  ('ros', 0.875),
#  ('pyewacket', 0.875),
#  ('roo', 0.875),
#  ('suo', 0.875),
#  ('chalo', 0.875),
#  ('tulipe', 0.875),
#  ('remer', 0.875),
#  ('beban', 0.875),
#  ('gordone', 0.875),
#  ('sirico', 0.875),
#  ('mridul', 0.875),
#  ('hightower', 0.875),
#  ('citizenx', 0.875),
#  ('heartbreakingly', 0.875),
#  ('cleanliness', 0.875),
#  ('ethier', 0.875),
#  ('pom', 0.875),
#  ('beulah', 0.875),
#  ('mcclurg', 0.875),
#  ('bondi', 0.875),
#  ('cj', 0.875),
#  ('marylee', 0.875),
#  ('rawlins', 0.875),
#  ('thierry', 0.875),
#  ('reassuring', 0.875),
#  ('rataud', 0.875),
#  ('sadashiv', 0.875),
#  ('unheralded', 0.875),
#  ('households', 0.875),
#  ('farlan', 0.875),
#  ('tachiguishi', 0.875),
#  ('junkermann', 0.875),
#  ('laudenbach', 0.875),
#  ('sissi', 0.875),
#  ('shoveller', 0.875),
#  ('evocation', 0.875),
#  ('evacuee', 0.875),
#  ('princeton', 0.875),
#  ('kasturba', 0.875),
#  ('unwillingly', 0.875),
#  ('dormael', 0.875),
#  ('kurtwood', 0.875),
#  ('tur', 0.875),
#  ('ripner', 0.875),
#  ('douglass', 0.875),
#  ('cantankerous', 0.875),
#  ('gilchrist', 0.875),
#  ('brak', 0.875),
#  ('demeanour', 0.875),
#  ('gedde', 0.875),
#  ('canto', 0.875),
#  ('jeter', 0.875),
#  ('concubine', 0.875),
#  ('moronie', 0.875),
#  ('krimi', 0.875),
#  ('tagge', 0.875),
#  ('beguiling', 0.875),
#  ('chyna', 0.875),
#  ('enlisting', 0.875),
#  ('steckert', 0.875),
#  ('faerie', 0.875),
#  ('sortie', 0.875),
#  ('schmid', 0.875),
#  ('corrine', 0.875),
#  ('hlots', 0.875),
#  ('sable', 0.875),
#  ('wymer', 0.875),
#  ('passworthy', 0.875),
#  ('kurasawa', 0.875),
#  ('chancery', 0.875),
#  ('piaf', 0.875),
#  ('doozy', 0.875),
#  ('zarabeth', 0.875),
#  ('reopened', 0.875),
#  ('margarethe', 0.875),
#  ('taker', 0.875),
#  ('izumo', 0.875),
#  ('radioactivity', 0.875),
#  ('melle', 0.875),
#  ('cantillana', 0.875),
#  ('dickory', 0.875),
#  ('trusts', 0.875),
#  ('solvang', 0.875),
#  ('edelman', 0.875),
#  ('haughty', 0.875),
#  ('vinson', 0.875),
#  ('trudi', 0.875),
#  ('riedelsheimer', 0.875),
#  ('reckoned', 0.875),
#  ('yamada', 0.875),
#  ('differing', 0.875),
#  ('scaffolding', 0.875),
#  ('amrapurkar', 0.875),
#  ('wastrel', 0.875),
#  ('castorini', 0.875),
#  ('cosimo', 0.875),
#  ('madhavi', 0.875),
#  ('kagan', 0.875),
#  ('pransky', 0.875),
#  ('antonia', 0.875),
#  ('jaco', 0.875),
#  ('catscratch', 0.875),
#  ('donlan', 0.875),
#  ('kazuhiro', 0.875),
#  ('sweid', 0.875),
#  ('chomet', 0.875),
#  ('morand', 0.875),
#  ('carmela', 0.875),
#  ('orla', 0.875),
#  ('konvitz', 0.875),
#  ('lta', 0.875),
#  ('bogarde', 0.875),
#  ('momo', 0.875),
#  ('altair', 0.875),
#  ('hersholt', 0.875),
#  ('kikuno', 0.875),
#  ('dauphine', 0.875),
#  ('marolla', 0.875),
#  ('scribe', 0.875),
#  ('milder', 0.875),
#  ('akane', 0.875),
#  ('zeenat', 0.875),
#  ('oberon', 0.875),
#  ('persistence', 0.875),
#  ('dirtiest', 0.875),
#  ('yaara', 0.875),
#  ('zapatti', 0.875),
#  ('laroche', 0.875),
#  ('stunner', 0.875),
#  ('vizier', 0.875),
#  ('aro', 0.875),
#  ('misha', 0.875),
#  ('attaches', 0.875),
#  ('reservations', 0.875),
#  ('mellisa', 0.875),
#  ('recognizably', 0.875),
#  ('frills', 0.875),
#  ('mavericks', 0.875),
#  ('glaser', 0.875),
#  ('novela', 0.875),
#  ('nanavati', 0.875),
#  ('valle', 0.875),
#  ('steppers', 0.875),
#  ('rending', 0.875),
#  ('doghi', 0.875),
#  ('sabriye', 0.875),
#  ('burnford', 0.875),
#  ('durbin', 0.8717948717948718),
#  ('braveheart', 0.8714285714285714),
#  ('vonnegut', 0.8703703703703703),
#  ('gandhi', 0.8702290076335878),
#  ('sirk', 0.87),
#  ('bannister', 0.8695652173913043),
#  ('ungar', 0.8695652173913043),
#  ('girlfight', 0.8695652173913043),
#  ('manny', 0.8695652173913043),
#  ('jud', 0.8695652173913043),
#  ('kazan', 0.8695652173913043),
#  ('homeward', 0.8695652173913043),
#  ('montrose', 0.8695652173913043),
#  ('hundstage', 0.8695652173913043),
#  ('natali', 0.8679245283018868),
#  ('pita', 0.8648648648648649),
#  ('mccoy', 0.8641975308641975),
#  ('tully', 0.8636363636363636),
#  ('sweetly', 0.8636363636363636),
#  ('hickok', 0.8636363636363636),
#  ('gigi', 0.8636363636363636),
#  ('zentropa', 0.8636363636363636),
#  ('linklater', 0.8636363636363636),
#  ('mccartney', 0.8636363636363636),
#  ('aborigines', 0.8636363636363636),
#  ('elia', 0.8636363636363636),
#  ('othello', 0.8617021276595744),
#  ('cheadle', 0.8615384615384616),
#  ('novak', 0.8602150537634409),
#  ('flawless', 0.8592592592592593),
#  ('pinto', 0.8571428571428571),
#  ('knoller', 0.8571428571428571),
#  ('shayan', 0.8571428571428571),
#  ('treize', 0.8571428571428571),
#  ('supper', 0.8571428571428571),
#  ('machi', 0.8571428571428571),
#  ('ghulam', 0.8571428571428571),
#  ('holroyd', 0.8571428571428571),
#  ('healey', 0.8571428571428571),
#  ('pieuvres', 0.8571428571428571),
#  ('adapts', 0.8571428571428571),
#  ('dramatisations', 0.8571428571428571),
#  ('urbaniak', 0.8571428571428571),
#  ('fleshes', 0.8571428571428571),
#  ('scorpione', 0.8571428571428571),
#  ('escalate', 0.8571428571428571),
#  ('spacious', 0.8571428571428571),
#  ('sumitra', 0.8571428571428571),
#  ('corps', 0.8571428571428571),
#  ('himmelen', 0.8571428571428571),
#  ('naissance', 0.8571428571428571),
#  ('fossey', 0.8571428571428571),
#  ('chadha', 0.8571428571428571),
#  ('pemberton', 0.8571428571428571),
#  ('riverside', 0.8571428571428571),
#  ('sweltering', 0.8571428571428571),
#  ('andretti', 0.8571428571428571),
#  ('dodes', 0.8571428571428571),
#  ('clapton', 0.8571428571428571),
#  ('elsa', 0.8571428571428571),
#  ('shimmering', 0.8571428571428571),
#  ('fraternal', 0.8571428571428571),
#  ('boz', 0.8571428571428571),
#  ('harlen', 0.8571428571428571),
#  ('incisive', 0.8571428571428571),
#  ('kwon', 0.8571428571428571),
#  ('mimieux', 0.8571428571428571),
#  ('jarada', 0.8571428571428571),
#  ('onassis', 0.8571428571428571),
#  ('aquaman', 0.8571428571428571),
#  ('browder', 0.8571428571428571),
#  ('gilson', 0.8571428571428571),
#  ('kazakos', 0.8571428571428571),
#  ('ohad', 0.8571428571428571),
#  ('byington', 0.8571428571428571),
#  ('domini', 0.8571428571428571),
#  ('yoakam', 0.8571428571428571),
#  ('horstachio', 0.8571428571428571),
#  ('blimp', 0.8571428571428571),
#  ('solino', 0.8571428571428571),
#  ('reece', 0.8571428571428571),
#  ('lasalle', 0.8571428571428571),
#  ('ntsc', 0.8571428571428571),
#  ('fallwell', 0.8571428571428571),
#  ('novarro', 0.8571428571428571),
#  ('cybersix', 0.8571428571428571),
#  ('seachd', 0.8571428571428571),
#  ('buccaneer', 0.8571428571428571),
#  ('letty', 0.8571428571428571),
#  ('anisio', 0.8571428571428571),
#  ('tenure', 0.8571428571428571),
#  ('affirmation', 0.8571428571428571),
#  ('circumstantial', 0.8571428571428571),
#  ('weill', 0.8571428571428571),
#  ('bregana', 0.8571428571428571),
#  ('haute', 0.8571428571428571),
#  ('thoughtfulness', 0.8571428571428571),
#  ('frwl', 0.8571428571428571),
#  ('overhyped', 0.8571428571428571),
#  ('fresnay', 0.8571428571428571),
#  ('repressive', 0.8571428571428571),
#  ('bromell', 0.8571428571428571),
#  ('pilger', 0.8571428571428571),
#  ('hatcher', 0.8571428571428571),
#  ('shaadi', 0.8571428571428571),
#  ('flamenco', 0.8571428571428571),
#  ('vulcans', 0.8571428571428571),
#  ('kazihiro', 0.8571428571428571),
#  ('paradoxes', 0.8571428571428571),
#  ('choo', 0.8571428571428571),
#  ('lesbos', 0.8571428571428571),
#  ('coalwood', 0.8571428571428571),
#  ('blyth', 0.8571428571428571),
#  ('puro', 0.8571428571428571),
#  ('cloudkicker', 0.8571428571428571),
#  ('ond', 0.8571428571428571),
#  ('cuoco', 0.8571428571428571),
#  ('fenech', 0.8571428571428571),
#  ('graaff', 0.8571428571428571),
#  ('zara', 0.8571428571428571),
#  ('unduly', 0.8571428571428571),
#  ('swatch', 0.8571428571428571),
#  ('shogo', 0.8571428571428571),
#  ('alonzo', 0.8571428571428571),
#  ('christy', 0.8571428571428571),
#  ('settlers', 0.8571428571428571),
#  ('restart', 0.8571428571428571),
#  ('transitional', 0.8571428571428571),
#  ('blore', 0.8571428571428571),
#  ('ike', 0.8571428571428571),
#  ('lebowski', 0.8571428571428571),
#  ('katzir', 0.8571428571428571),
#  ('alisan', 0.8571428571428571),
#  ('gianfranco', 0.8571428571428571),
#  ('krupa', 0.8571428571428571),
#  ('tuvok', 0.8571428571428571),
#  ('kidnappings', 0.8571428571428571),
#  ('collier', 0.8571428571428571),
#  ('redrum', 0.8571428571428571),
#  ('beirut', 0.8571428571428571),
#  ('quartier', 0.8571428571428571),
#  ('styne', 0.8571428571428571),
#  ('wallah', 0.8571428571428571),
#  ('konkona', 0.8571428571428571),
#  ('donaggio', 0.8571428571428571),
#  ('quais', 0.8571428571428571),
#  ('bibbidi', 0.8571428571428571),
#  ('oshin', 0.8571428571428571),
#  ('miryang', 0.8571428571428571),
#  ('turpin', 0.8571428571428571),
#  ('sylvain', 0.8571428571428571),
#  ('recognising', 0.8571428571428571),
#  ('pelletier', 0.8571428571428571),
#  ('illusionist', 0.8571428571428571),
#  ('timoner', 0.8571428571428571),
#  ('matures', 0.8571428571428571),
#  ('bristles', 0.8571428571428571),
#  ('dilly', 0.8571428571428571),
#  ('tati', 0.8571428571428571),
#  ('piedras', 0.8571428571428571),
#  ('sadler', 0.8571428571428571),
#  ('yelli', 0.8571428571428571),
#  ('coleridge', 0.8571428571428571),
#  ('locust', 0.8571428571428571),
#  ('lotus', 0.8571428571428571),
#  ('cragg', 0.8571428571428571),
#  ('solent', 0.8571428571428571),
#  ('repentance', 0.8571428571428571),
#  ('asagoro', 0.8571428571428571),
#  ('halprin', 0.8571428571428571),
#  ('blooms', 0.8571428571428571),
#  ('madigan', 0.8571428571428571),
#  ('cheang', 0.8571428571428571),
#  ('hallgren', 0.8571428571428571),
#  ('literacy', 0.8571428571428571),
#  ('candyman', 0.8571428571428571),
#  ('klaang', 0.8571428571428571),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('dhol', 0.0),
#  ('murdock', 0.0),
#  ('leaden', 0.0),
#  ('mouthful', 0.0),
#  ('sued', 0.0),
#  ('kargil', 0.0),
#  ('noggin', 0.0),
#  ('kober', 0.0),
#  ('reilly', 0.0),
#  ('proog', 0.0),
#  ('earrings', 0.0),
#  ('bancroft', 0.0),
#  ('pitchfork', 0.0),
#  ('keeffe', 0.0),
#  ('flemming', 0.0),
#  ('crystina', 0.0),
#  ('advani', 0.0),
#  ('wayan', 0.0),
#  ('shite', 0.0),
#  ('mma', 0.0),
#  ('appliances', 0.0),
#  ('grinds', 0.0),
#  ('cornfield', 0.0),
#  ('clowns', 0.0),
#  ('charmless', 0.0),
#  ('munchie', 0.0),
#  ('dullest', 0.0),
#  ('ardelean', 0.0),
#  ('bettina', 0.0),
#  ('pinocchio', 0.0)]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5aba7220-5897-48e2-b15c-eea18b9d8744">Loading BokehJS ...</span>
#     </div>

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="61cea46a-ef47-4a57-b19b-e8ac5dab02fc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("61cea46a-ef47-4a57-b19b-e8ac5dab02fc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("61cea46a-ef47-4a57-b19b-e8ac5dab02fc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '61cea46a-ef47-4a57-b19b-e8ac5dab02fc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b80d3f94-ae8b-4a42-9e55-9e779a55499c":{"roots":{"references":[{"attributes":{"callback":null},"id":"be9dbeae-0f83-4c9f-b316-f22285d2cd74","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["top","right","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"a1c42c39-5e96-4613-bc7e-cd7a6889d6c9","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"8c013f31-4f71-4268-8d40-ac7b723d3117","type":"Quad"},{"attributes":{},"id":"c50b753d-6268-46b4-8375-b07d1b7719f2","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"3f8a230d-4a20-467a-a002-0d1e8d9baf82","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Word Positive/Negative Affinity Distribution"},"id":"0eeaca6f-6f9e-4c76-a985-a93ea0aea485","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"4fa581e6-1af0-4514-8898-d3ad7b21eca0","type":"BasicTicker"}},"id":"fed9c8b6-a12d-4727-a674-bb2281152f32","type":"Grid"},{"attributes":{"data_source":{"id":"a1c42c39-5e96-4613-bc7e-cd7a6889d6c9","type":"ColumnDataSource"},"glyph":{"id":"8f4f8723-c873-43e4-ae57-23eddd413b04","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"8c013f31-4f71-4268-8d40-ac7b723d3117","type":"Quad"},"selection_glyph":null},"id":"7ef64e53-e54b-4a3e-b1e5-9ae1ae9d4d9f","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"8f4f8723-c873-43e4-ae57-23eddd413b04","type":"Quad"},{"attributes":{},"id":"a60a4154-0305-4599-8907-ed694e0d681a","type":"ToolEvents"},{"attributes":{"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"}},"id":"efc4b7b1-cf68-4704-a1ff-6d69c6aac243","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"71e49d5d-e43b-4d61-ba71-e2952187f19c","type":"BasicTickFormatter"},"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"337d1702-1803-483f-9c7d-f0c0460cce2c","type":"BasicTicker"}},"id":"086c6e01-6af9-4674-8589-fa7942d9d684","type":"LinearAxis"},{"attributes":{"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"}},"id":"ae6770d5-de53-485f-9eb3-86aa2198d43f","type":"PanTool"},{"attributes":{},"id":"4fa581e6-1af0-4514-8898-d3ad7b21eca0","type":"BasicTicker"},{"attributes":{"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"337d1702-1803-483f-9c7d-f0c0460cce2c","type":"BasicTicker"}},"id":"835e73c1-bf2c-4cbb-97cd-d88c15b38eca","type":"Grid"},{"attributes":{"formatter":{"id":"c50b753d-6268-46b4-8375-b07d1b7719f2","type":"BasicTickFormatter"},"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"4fa581e6-1af0-4514-8898-d3ad7b21eca0","type":"BasicTicker"}},"id":"d22c897d-6eab-42d2-941e-138619e3f0b6","type":"LinearAxis"},{"attributes":{"plot":{"id":"b067cdbe-ddd3-42a7-8eee-310e823f9bf6","subtype":"Figure","type":"Plot"}},"id":"65c1a07c-66ec-4569-aa46-c9133c421071","type":"SaveTool"},{"attributes":{},"id":"71e49d5d-e43b-4d61-ba71-e2952187f19c","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ae6770d5-de53-485f-9eb3-86aa2198d43f","type":"PanTool"},{"id":"efc4b7b1-cf68-4704-a1ff-6d69c6aac243","type":"WheelZoomTool"},{"id":"8a79d97d-27bf-42d6-ad78-f6b42812525f","type":"ResetTool"},{"id":"65c1a07c-66ec-4569-aa46-c9133c421071","type":"SaveTool"}]},"id":"b57d991 ...

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="87c43551-a45a-4384-ab9f-d26d3055383f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("87c43551-a45a-4384-ab9f-d26d3055383f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("87c43551-a45a-4384-ab9f-d26d3055383f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '87c43551-a45a-4384-ab9f-d26d3055383f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c6ce90f2-28a3-4954-b1b6-16c934a584a8":{"roots":{"references":[{"attributes":{},"id":"67f9b2fe-64fe-45c6-9457-b51730430299","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"}},"id":"e1dc4c61-63f5-4bae-a407-c7a6fef70e8e","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"}},"id":"6529a780-132a-4292-a81c-d69170fefc0f","type":"ResetTool"},{"attributes":{},"id":"f44944e1-52a6-4c6c-adf1-5569f358b87c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"}},"id":"f8ef3e29-887a-418d-be56-fe20307ee854","type":"PanTool"},{"attributes":{"formatter":{"id":"f44944e1-52a6-4c6c-adf1-5569f358b87c","type":"BasicTickFormatter"},"plot":{"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6578727-dbc3-4183-a06b-241fa152fbe1","type":"BasicTicker"}},"id":"d6442a79-0440-473b-96ba-4f9e96681444","type":"LinearAxis"},{"attributes":{"below":[{"id":"d6442a79-0440-473b-96ba-4f9e96681444","type":"LinearAxis"}],"left":[{"id":"8b04e32e-2c8b-48a4-88c2-613a6ed90c70","type":"LinearAxis"}],"renderers":[{"id":"d6442a79-0440-473b-96ba-4f9e96681444","type":"LinearAxis"},{"id":"da76f01f-16e4-44d7-98ad-e13d2a8ca212","type":"Grid"},{"id":"8b04e32e-2c8b-48a4-88c2-613a6ed90c70","type":"LinearAxis"},{"id":"5c1e40ef-2b0a-41db-8466-08c9ed1e2950","type":"Grid"},{"id":"200b881a-9a9c-4aed-9346-5891642a344a","type":"GlyphRenderer"}],"title":{"id":"3b09ffd2-2662-4276-8a7c-1ba0bdef911f","type":"Title"},"tool_events":{"id":"faa8a6d1-eeb5-431d-a6b7-1a114f51cc7a","type":"ToolEvents"},"toolbar":{"id":"5a01f79e-5550-4da2-b1ee-e5183f5b4768","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"b14641cd-4141-42e1-bea9-d97b393b6dee","type":"DataRange1d"},"y_range":{"id":"2246f55c-3d81-4ab9-bc68-41f1f35488db","type":"DataRange1d"}},"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"abfc0728-bce8-4166-886b-0b19e3954bc6","type":"Quad"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f8ef3e29-887a-418d-be56-fe20307ee854","type":"PanTool"},{"id":"e1dc4c61-63f5-4bae-a407-c7a6fef70e8e","type":"WheelZoomTool"},{"id":"6529a780-132a-4292-a81c-d69170fefc0f","type":"ResetTool"},{"id":"0436a838-3045-45b7-abb1-58be26d6d872","type":"SaveTool"}]},"id":"5a01f79e-5550-4da2-b1ee-e5183f5b4768","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["top","right","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"e7c5a509-5cdd-45c7-af78-85e42e846ae9","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"},"ticker":{"id":"c6578727-dbc3-4183-a06b-241fa152fbe1","type":"BasicTicker"}},"id":"da76f01f-16e4-44d7-98ad-e13d2a8ca212","type":"Grid"},{"attributes":{},"id":"faa8a6d1-eeb5-431d-a6b7-1a114f51cc7a","type":"ToolEvents"},{"attributes":{"callback":null},"id":"2246f55c-3d81-4ab9-bc68-41f1f35488db","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"4b26e565-b626-48e9-a32b-1e70a71b81ae","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce608f94-14ad-474b-bec8-5af95e3d6e35","type":"BasicTicker"}},"id":"5c1e40ef-2b0a-41db-8466-08c9ed1e2950","type":"Grid"},{"attributes":{"callback":null},"id":"b14641cd-4141-42e1-bea9-d97b393b6dee","type":"DataRange1d"},{"attributes":{},"id":"c6578727-dbc3-4183-a06b-241fa152fbe1","type":"BasicTicker"},{"attributes":{"plot":null,"text":"The frequency distribution of the words in our corpu ...

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    ## New for Project 6: added min_count and polarity_cutoff parameters
    def __init__(self, reviews,labels,min_count = 10,polarity_cutoff = 0.1,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            min_count(int) - Words should only be added to the vocabulary 
                             if they occur more than this many times
            polarity_cutoff(float) - The absolute value of a word's positive-to-negative
                                     ratio must be at least this big to be considered.
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        ## New for Project 6: added min_count and polarity_cutoff arguments to pre_process_data call
        self.pre_process_data(reviews, labels, polarity_cutoff, min_count)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    ## New for Project 6: added min_count and polarity_cutoff parameters
    def pre_process_data(self, reviews, labels, polarity_cutoff, min_count):
        
        ## ----------------------------------------
        ## New for Project 6: Calculate positive-to-negative ratios for words before
        #                     building vocabulary
        #
        positive_counts = Counter()
        negative_counts = Counter()
        total_counts = Counter()

        for i in range(len(reviews)):
            if(labels[i] == 'POSITIVE'):
                for word in reviews[i].split(" "):
                    positive_counts[word] += 1
                    total_counts[word] += 1
            else:
                for word in reviews[i].split(" "):
                    negative_counts[word] += 1
                    total_counts[word] += 1

        pos_neg_ratios = Counter()

        for term,cnt in list(total_counts.most_common()):
            if(cnt >= 50):
                pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
                pos_neg_ratios[term] = pos_neg_ratio

        for word,ratio in pos_neg_ratios.most_common():
            if(ratio > 1):
                pos_neg_ratios[word] = np.log(ratio)
            else:
                pos_neg_ratios[word] = -np.log((1 / (ratio + 0.01)))
        #
        ## end New for Project 6
        ## ----------------------------------------

        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                ## New for Project 6: only add words that occur at least min_count times
                #                     and for words with pos/neg ratios, only add words
                #                     that meet the polarity_cutoff
                if(total_counts[word] > min_count):
                    if(word in pos_neg_ratios.keys()):
                        if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
                            review_vocab.add(word)
                    else:
                        review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))

        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        ## New for Project 5: Removed self.layer_0; added self.layer_1
        # The input layer, a two-dimensional matrix with shape 1 x hidden_nodes
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    ## New for Project 5: Removed update_input_layer function
    
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    ## New for Project 5: changed name of first parameter form 'training_reviews' 
    #                     to 'training_reviews_raw'
    def train(self, training_reviews_raw, training_labels):

        ## New for Project 5: pre-process training reviews so we can deal 
        #                     directly with the indices of non-zero inputs
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))

        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0

        # Remember when we started for printing time statistics
        start = time.time()
        
        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            ## New for Project 5: Removed call to 'update_input_layer' function
            #                     because 'layer_0' is no longer used

            # Hidden layer
            ## New for Project 5: Add in only the weights for non-zero items
            self.layer_1 *= 0
            for index in review:
                self.layer_1 += self.weights_0_1[index]

            # Output layer
            ## New for Project 5: changed to use 'self.layer_1' instead of 'local layer_1'
            layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            
            
            #### Implement the backward pass here ####
            ### Backward pass ###

            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            ## New for Project 5: changed to use 'self.layer_1' instead of local 'layer_1'
            self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            
            ## New for Project 5: Only update the weights that were used in the forward pass
            for index in review:
                self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate # update input-to-hidden weights with gradient descent step

            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # Run a forward pass through the network, like in the "train" function.
        
        ## New for Project 5: Removed call to update_input_layer function
        #                     because layer_0 is no longer used

        # Hidden layer
        ## New for Project 5: Identify the indices used in the review and then add
        #                     just those weights to layer_1 
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        
        # Output layer
        ## New for Project 5: changed to use self.layer_1 instead of local layer_1
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
         
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-f9915c47f97c> in <module>()
# ----> 1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
#       2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-70-f6ce5925170f> in __init__(self, reviews, labels, min_count, polarity_cutoff, hidden_nodes, learning_rate)
#      26         # is ready for training
#      27         ## New for Project 6: added min_count and polarity_cutoff arguments to pre_process_data call
# ---> 28         self.pre_process_data(reviews, labels, polarity_cutoff, min_count)
#      29
#      30         # Build the network to have the number of hidden nodes and the learning rate that
#
# <ipython-input-70-f6ce5925170f> in pre_process_data(self, reviews, labels, polarity_cutoff, min_count)
#      78                 #                     that meet the polarity_cutoff
#      79                 if(total_counts[word] > min_count):
# ---> 80                     if(word in pos_neg_ratios.keys()):
#      81                         if((pos_neg_ratios[word] >= polarity_cutoff) or (pos_neg_ratios[word] <= -polarity_cutoff)):
#      82                             review_vocab.add(word)
#
# KeyboardInterrupt:

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
